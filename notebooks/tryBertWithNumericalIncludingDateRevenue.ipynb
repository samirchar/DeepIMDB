# %%
import transformers
print(transformers.__version__)
# Out:
# 4.18.0

# %%
# !pip install -U transformers
# !pip install -U datasets
# !pip install optuna
import os
import sys
HOME = os.path.abspath('..')
sys.path.append(HOME)
os.chdir(HOME)
import pandas as pd
#!pip install transformers
from transformers import RobertaConfig, RobertaModel,RobertaForSequenceClassification, Trainer,AutoModelForSequenceClassification, EarlyStoppingCallback 
from transformers import AutoTokenizer
from transformers.models.roberta import RobertaPreTrainedModel
import torch
from torch import nn
from transformers import TrainingArguments
import glob
import optuna
from itertools import product
import numpy as np
from pprint import pprint

# %%
MODEL_NAME =  "distilbert-base-uncased" #"roberta-base" 
TARGET_COL = 'revenue_worldwide_BOM'#'revenue_worldwide_BOM'#'averageRating'
MODEL_FOLDER = 'text_with_numerical_including_date'#'only_text_features'#'everything_as_text'
text_input_col = 'text_input'
CATEGORIES_AS_TEXT = True
NUMERIC_AS_TEXT = False
DATE_AS_TEXT = False
ADJUST_INFLATION = False
USE_COLUMN_NAMES = False
COLAB = False
DEBUG = False

FINAL_MODEL_NAME = f"{MODEL_NAME}-{TARGET_COL}"

if ADJUST_INFLATION:
    FINAL_MODEL_NAME+='-inflation_adjusted'
    
if USE_COLUMN_NAMES:
    FINAL_MODEL_NAME+='-with_column_names'
    

FINAL_MODEL_PATH = f'models/{MODEL_FOLDER}/{FINAL_MODEL_NAME}'
TRIALS_DF_PATH = f'models/{MODEL_FOLDER}/{FINAL_MODEL_NAME}_hparams_trials.csv'
TEST_PERFORMANCE_PATH = f'models/{MODEL_FOLDER}/{FINAL_MODEL_NAME}_test_stats_best_model.csv'
    
if USE_COLUMN_NAMES:
    assert CATEGORIES_AS_TEXT|NUMERIC_AS_TEXT|DATE_AS_TEXT, "can't use column names as text if there are no columns to treat as text!"
    
print('Final model name: ',FINAL_MODEL_NAME)
print('Saving at: ',MODEL_FOLDER)


if COLAB == True:
  if not os.path.exists('data'):
    os.mkdir('data')
  if not os.path.exists('data/processed'):
    os.mkdir('data/processed')

  drive.mount('/content/gdrive/')
  for filename in glob.glob(os.path.join('gdrive/MyDrive/atdl', '*.*')):
      shutil.copy(filename, 'data/processed')
# Out:
# Final model name:  distilbert-base-uncased-revenue_worldwide_BOM
# Saving at:  text_with_numerical_including_date

# %%
text_cols = ['text_input']
numerical_cols = ['normalized_Budget', 'normalized_runtimeMinutes','normalized_year','normalized_month','normalized_date']

column_info_dict = {
    'text_cols': text_cols,
    'num_cols': numerical_cols,
}

# %%
class TorchTabularTextDataset(torch.utils.data.Dataset):
    """
    :obj:`TorchDataset` wrapper for text dataset with categorical features
    and numerical features
    Parameters:
        encodings (:class:`transformers.BatchEncoding`):
            The output from encode_plus() and batch_encode() methods (tokens, attention_masks, etc) of
            a transformers.PreTrainedTokenizer
        categorical_feats (:class:`numpy.ndarray`, of shape :obj:`(n_examples, categorical feat dim)`, `optional`, defaults to :obj:`None`):
            An array containing the preprocessed categorical features
        numerical_feats (:class:`numpy.ndarray`, of shape :obj:`(n_examples, numerical feat dim)`, `optional`, defaults to :obj:`None`):
            An array containing the preprocessed numerical features
        labels (:class: list` or `numpy.ndarray`, `optional`, defaults to :obj:`None`):
            The labels of the training examples
        class_weights (:class:`numpy.ndarray`, of shape (n_classes),  `optional`, defaults to :obj:`None`):
            Class weights used for cross entropy loss for classification
        df (:class:`pandas.DataFrame`, `optional`, defaults to :obj:`None`):
            Model configuration class with all the parameters of the model.
            This object must also have a tabular_config member variable that is a
            TabularConfig instance specifying the configs for TabularFeatCombiner
    """
    def __init__(self,
                 encodings,
                 categorical_feats,
                 numerical_feats,
                 labels=None,
                 df=None,
                 label_list=None,
                 class_weights=None
                 ):
        self.df = df
        self.encodings = encodings
        self.cat_feats = categorical_feats
        self.numerical_feats = numerical_feats
        self.labels = labels
        self.class_weights = class_weights
        self.label_list = label_list if label_list is not None else [i for i in range(len(np.unique(labels)))]

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx])
                for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]) if self.labels is not None  else None
        item['cat_feats'] = torch.tensor(self.cat_feats[idx]).float() \
            if self.cat_feats is not None else torch.zeros(0)
        item['numerical_feats'] = torch.tensor(self.numerical_feats[idx]).float()\
            if self.numerical_feats is not None else torch.zeros(0)
        return item

    def __len__(self):
        return len(self.labels)

    def get_labels(self):
        """returns the label names for classification"""
        return self.label_list

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

def process_text_data(data_:pd.DataFrame,text_col,padding ="max_length", truncation = True, na_filler = ""):

    '''
    
    '''
    data = data_.copy()
    data[text_col] = data[text_col].fillna(na_filler)
    encodings = tokenizer(data[text_col].tolist(), padding=padding, truncation=truncation)
    return encodings
    

def columns_to_single_text(df,cols_to_transform,new_col_name = 'text_input',sep = tokenizer.sep_token,nan_replacement = tokenizer.unk_token ):

  '''
  
  Creates a new column called new_col_name with with all columns in cols_to_transform concatenated into a single text
  '''
  df[new_col_name] = df[cols_to_transform].astype(str).replace('nan',nan_replacement).agg(f' {sep} '.join, axis=1)


class NAFiller:

  def __init__(self,train):
    self.train = train

  def fit(self,column = 'Budget',groupby=['top_genre','top_country']):
    self.mapping = self.train.groupby(groupby)[column].median().reset_index()
    self.mapping = self.mapping.rename(columns={column:'na_filler'})
    self.median = self.train[column].median()
    self.column=column


  def transform(self,test,round = False):
    self.na_filler = test.merge(self.mapping,how='left')['na_filler']
    self.na_filler = self.na_filler.fillna(self.median)

    test[self.column] = test[self.column].reset_index(drop=True).fillna(self.na_filler).values

    if round:
      test[self.column] = test[self.column].round().astype(int)
      


  def fit_transform(self,test,column = 'Budget',groupby=['top_genre','top_country']):
    self.fit(column,groupby)
    self.transform()
    self.column=column
        

def create_dataset_split(split,text_cols,text_input_col,TARGET_COL):
    
  if TARGET_COL == 'revenue_worldwide_BOM':
    split[TARGET_COL] = np.log1p(split[TARGET_COL])
    print('log transforming target')
    

  #If all columns in text_cols are combined into a single text. A n
  columns_to_single_text(split,text_cols)

  #Get split encodings
  split_encodings = process_text_data(split,text_input_col)

  #get labels
  split_labels = split[TARGET_COL].tolist()

  split[numerical_cols] = split[numerical_cols].astype(float)
  numerical_feats = split[numerical_cols].values

  #Create dataset objects
  # split_dataset = IMDbDataset(split_encodings, split_labels)
  split_dataset = TorchTabularTextDataset(split_encodings,
                 None,
                 numerical_feats,
                 split_labels,
                 split,
                 None,
                 None)

  return split_dataset


def get_model():
    return AutoModelForSequenceClassification.from_pretrained(MODEL_NAME,
                                                         problem_type='regression',
                                                         num_labels=1)
def get_model_by_name(model_name):
    return AutoModelForSequenceClassification.from_pretrained(model_name,
                                                         problem_type='regression',
                                                         num_labels=1
                                                        )

# %%
all_cols =  ['Budget',
             'averageRating',
             'cast',
             'countries',
             'director',
             'genres',
             'imdb_id',
             'languages',
             'overview',
             'production companies',
             'release_date',
             'revenue_worldwide_BOM',
             'runtimeMinutes',
             'title']

categoric_cols = ['cast',
                  'countries',
                  'director',
                  'genres',
                  'languages',
                  'production companies']

text_cols = ['title','overview']                  
date_cols = ['release_date']
numeric_cols = ['normalized_Budget','normalized_runtimeMinutes','normalized_year','normalized_month','normalized_date']

if CATEGORIES_AS_TEXT:
  text_cols+=categoric_cols

if NUMERIC_AS_TEXT:
  text_cols+=numeric_cols

if DATE_AS_TEXT:
  text_cols+=date_cols

train_ids = pd.read_csv('notebooks/data/train_revised_advdlproject.csv',usecols=['imdb_id'])['imdb_id'].tolist()
val_ids = pd.read_csv('notebooks/data/val_revised_advdlproject.csv',usecols=['imdb_id'])['imdb_id'].tolist()
test_ids = pd.read_csv('notebooks/data/test_revised_advdlproject.csv',usecols=['imdb_id'])['imdb_id'].tolist()
df = pd.read_csv('notebooks/data/df_revised_advdlproject.csv',usecols = all_cols,parse_dates=['release_date']).sample(frac=1,random_state=42) #shuffle


df[categoric_cols] = df[categoric_cols].apply(lambda x: x.str.replace('|',', '),axis=0) #Change pipe to comma, its more meaningful
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
#Additional auxilary columns
df['top_genre'] = df['genres'].apply(lambda x: x.split(', ')[0])
df['top_country'] = df['countries'].apply(lambda x: x.split(', ')[0] if isinstance(x,str) else x)
df['year'] = df['release_date'].dt.year
df['month'] = df['release_date'].dt.month
df['date'] = df['release_date'].dt.day

# %%
#Create splits
if DEBUG:
    train = df[df['imdb_id'].isin(train_ids)].sample(frac=0.2)
    val = df[df['imdb_id'].isin(val_ids)].sample(frac=0.2)
    test = df[df['imdb_id'].isin(test_ids)]
else:
    train = df[df['imdb_id'].isin(train_ids)]
    val = df[df['imdb_id'].isin(val_ids)]
    test = df[df['imdb_id'].isin(test_ids)]


#Fill na in some columns with statistics
naf = NAFiller(train)
naf.fit(column = 'Budget',groupby=['top_genre','top_country','year'])
naf.transform(train,round=True)
naf.transform(val,round=True)
naf.transform(test,round=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
non_null_runtimeMinutes = train.loc[train['runtimeMinutes'] != '\\N']
median_val = non_null_runtimeMinutes['runtimeMinutes'].astype(int).median()

# %%
train['runtimeMinutes'].replace(r'\\N', str(int(median_val)), regex=True, inplace = True)
val['runtimeMinutes'].replace(r'\\N', str(int(median_val)), regex=True, inplace = True)
test['runtimeMinutes'].replace(r'\\N', str(int(median_val)), regex=True, inplace = True)
train['runtimeMinutes'] = train['runtimeMinutes'].astype(int)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(np.expand_dims(train['runtimeMinutes'].to_numpy(),0).T)
train['normalized_runtimeMinutes'] = scaler.transform(np.expand_dims(train['runtimeMinutes'].to_numpy(),0).T)
val['normalized_runtimeMinutes'] = scaler.transform(np.expand_dims(val['runtimeMinutes'].to_numpy(),0).T)
test['normalized_runtimeMinutes'] = scaler.transform(np.expand_dims(test['runtimeMinutes'].to_numpy(),0).T)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
scaler = StandardScaler()
scaler.fit(np.expand_dims(train['Budget'].to_numpy(),0).T)
train['normalized_Budget'] = scaler.transform(np.expand_dims(train['Budget'].to_numpy(),0).T)
val['normalized_Budget'] = scaler.transform(np.expand_dims(val['Budget'].to_numpy(),0).T)
test['normalized_Budget'] = scaler.transform(np.expand_dims(test['Budget'].to_numpy(),0).T)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
scaler = StandardScaler()
scaler.fit(np.expand_dims(train['year'].to_numpy(),0).T)
train['normalized_year'] = scaler.transform(np.expand_dims(train['year'].to_numpy(),0).T)
val['normalized_year'] = scaler.transform(np.expand_dims(val['year'].to_numpy(),0).T)
test['normalized_year'] = scaler.transform(np.expand_dims(test['year'].to_numpy(),0).T)

scaler = StandardScaler()
scaler.fit(np.expand_dims(train['month'].to_numpy(),0).T)
train['normalized_month'] = scaler.transform(np.expand_dims(train['month'].to_numpy(),0).T)
val['normalized_month'] = scaler.transform(np.expand_dims(val['month'].to_numpy(),0).T)
test['normalized_month'] = scaler.transform(np.expand_dims(test['month'].to_numpy(),0).T)

scaler = StandardScaler()
scaler.fit(np.expand_dims(train['date'].to_numpy(),0).T)
train['normalized_date'] = scaler.transform(np.expand_dims(train['date'].to_numpy(),0).T)
val['normalized_date'] = scaler.transform(np.expand_dims(val['date'].to_numpy(),0).T)
test['normalized_date'] = scaler.transform(np.expand_dims(test['date'].to_numpy(),0).T)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_dataset=create_dataset_split(train,text_cols,text_input_col,TARGET_COL)
val_dataset=create_dataset_split(val,text_cols,text_input_col,TARGET_COL)
test_dataset=create_dataset_split(test,text_cols,text_input_col,TARGET_COL)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# log transforming target
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# log transforming target
# log transforming target

# %%
num_labels = 1

# %%
from torch import nn
from transformers import DistilBertForSequenceClassification

# %%
class TabularConfig:
    r""" Config used for tabular combiner
    Args:
        mlp_division (int): how much to decrease each MLP dim for each additional layer
        combine_feat_method (str): The method to combine categorical and numerical features.
            See :obj:`TabularFeatCombiner` for details on the supported methods.
        mlp_dropout (float): dropout ratio used for MLP layers
        numerical_bn (bool): whether to use batchnorm on numerical features
        use_simple_classifier (bool): whether to use single layer or MLP as final classifier
        mlp_act (str): the activation function to use for finetuning layers
        gating_beta (float): the beta hyperparameters used for gating tabular data
            see the paper `Integrating Multimodal Information in Large Pretrained Transformers <https://www.aclweb.org/anthology/2020.acl-main.214.pdf>`_ for details
        numerical_feat_dim (int): the number of numerical features
        cat_feat_dim (int): the number of categorical features
    """
    def __init__(self,
                 num_labels,
                 mlp_division=4,
                 combine_feat_method='text_only',
                 mlp_dropout=0.1,
                 numerical_bn=True,
                 use_simple_classifier=True,
                 mlp_act='relu',
                 gating_beta=0.2,
                 numerical_feat_dim=0,
                 cat_feat_dim=0,
                 **kwargs
                 ):
        self.mlp_division = mlp_division
        self.combine_feat_method = combine_feat_method
        self.mlp_dropout = mlp_dropout
        self.numerical_bn = numerical_bn
        self.use_simple_classifier = use_simple_classifier
        self.mlp_act = mlp_act
        self.gating_beta = gating_beta
        self.numerical_feat_dim = numerical_feat_dim
        self.cat_feat_dim = cat_feat_dim
        self.num_labels = num_labels

# %%
import math
import torch
import torch.nn as nn
from torch.nn import CrossEntropyLoss, MSELoss


class MLP(nn.Module):
    """mlp can specify number of hidden layers and hidden layer channels"""

    def __init__(self, input_dim, output_dim, act='relu', num_hidden_lyr=2,
                 dropout_prob=0.5, return_layer_outs=False,
                 hidden_channels=None, bn=False):
        super().__init__()
        self.out_dim = output_dim
        self.dropout = nn.Dropout(dropout_prob)
        self.return_layer_outs = return_layer_outs
        if not hidden_channels:
            hidden_channels = [input_dim for _ in range(num_hidden_lyr)]
        elif len(hidden_channels) != num_hidden_lyr:
            raise ValueError(
                "number of hidden layers should be the same as the lengh of hidden_channels")
        self.layer_channels = [input_dim] + hidden_channels + [output_dim]
        self.act_name = act
        self.activation = create_act(act)
        self.layers = nn.ModuleList(list(
            map(self.weight_init, [nn.Linear(self.layer_channels[i], self.layer_channels[i + 1])
                                   for i in range(len(self.layer_channels) - 2)])))
        final_layer = nn.Linear(self.layer_channels[-2], self.layer_channels[-1])
        self.weight_init(final_layer,   activation='linear')
        self.layers.append(final_layer)

        self.bn = bn
        if self.bn:
            self.bn = nn.ModuleList([torch.nn.BatchNorm1d(dim) for dim in self.layer_channels[1:-1]])

    def weight_init(self, m, activation=None):
        if activation is None:
            activation = self.act_name
        torch.nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain(activation))
        return m

    def forward(self, x):
        """
        :param x: the input features
        :return: tuple containing output of MLP,
                and list of inputs and outputs at every layer
        """
        layer_inputs = [x]
        for i, layer in enumerate(self.layers):
            input = layer_inputs[-1]
            if layer == self.layers[-1]:
                layer_inputs.append(layer(input))
            else:
                if self.bn:
                    output = self.activation(self.bn[i](layer(input)))
                else:
                    output = self.activation(layer(input))
                layer_inputs.append(self.dropout(output))

        # model.store_layer_output(self, layer_inputs[-1])
        if self.return_layer_outs:
            return layer_inputs[-1], layer_inputs
        else:
            return layer_inputs[-1]


def calc_mlp_dims(input_dim, division=2, output_dim=1):
    dim = input_dim
    dims = []
    while dim > output_dim:
        dim = dim // division
        dims.append(int(dim))
    dims = dims[:-1]
    return dims


def create_act(act, num_parameters=None):
    if act == 'relu':
        return nn.ReLU()
    elif act == 'prelu':
        return nn.PReLU(num_parameters)
    elif act == 'sigmoid':
        return nn.Sigmoid()
    elif act == 'tanh':
        return nn.Tanh()
    elif act == 'linear':
        class Identity(nn.Module):
            def forward(self, x):
                return x

        return Identity()
    else:
        raise ValueError('Unknown activation function {}'.format(act))


def glorot(tensor):
    stdv = math.sqrt(6.0 / (tensor.size(-2) + tensor.size(-1)))
    if tensor is not None:
        tensor.data.uniform_(-stdv, stdv)


def zeros(tensor):
    if tensor is not None:
        tensor.data.fill_(0)


def hf_loss_func(inputs, classifier, labels, num_labels, class_weights):
    logits = classifier(inputs)
    if type(logits) is tuple:
        logits, layer_outputs = logits[0], logits[1]
    else:  # simple classifier
        layer_outputs = [inputs, logits]
    if labels is not None:
        if num_labels == 1:
            #  We are doing regression
            loss_fct = MSELoss()
            labels = labels.float()
            loss = loss_fct(logits.view(-1), labels.view(-1))
        else:
            loss_fct = CrossEntropyLoss(weight=class_weights)
            labels = labels.long()
            loss = loss_fct(logits.view(-1, num_labels), labels.view(-1))
    else:
        return None, logits, layer_outputs

    return loss, logits, layer_outputs

# %%
import torch
from torch import nn
import torch.nn.functional as F

# from .layer_utils import calc_mlp_dims, create_act, glorot, zeros, MLP


class TabularFeatCombiner(nn.Module):
    r"""
        Combiner module for combining text features with categorical and numerical features
        The methods of combining, specified by :obj:`tabular_config.combine_feat_method` are shown below.
        :math:`\mathbf{m}` denotes the combined multimodal features,
        :math:`\mathbf{x}` denotes the output text features from the transformer,
        :math:`\mathbf{c}` denotes the categorical features, :math:`\mathbf{t}` denotes the numerical features,
        :math:`h_{\mathbf{\Theta}}` denotes a MLP parameterized by :math:`\Theta`, :math:`W` denotes a weight matrix,
        and :math:`b` denotes a scalar bias
        - **text_only**
            .. math::
                \mathbf{m} = \mathbf{x}
        - **concat**
            .. math::
                \mathbf{m} = \mathbf{x} \, \Vert \, \mathbf{c} \, \Vert \, \mathbf{n}
        - **mlp_on_categorical_then_concat**
            .. math::
                \mathbf{m} = \mathbf{x} \, \Vert \, h_{\mathbf{\Theta}}( \mathbf{c}) \, \Vert \, \mathbf{n}
        - **individual_mlps_on_cat_and_numerical_feats_then_concat**
            .. math::
                \mathbf{m} = \mathbf{x} \, \Vert \, h_{\mathbf{\Theta_c}}( \mathbf{c}) \, \Vert \, h_{\mathbf{\Theta_n}}(\mathbf{n})
        - **mlp_on_concatenated_cat_and_numerical_feats_then_concat**
            .. math::
                \mathbf{m} = \mathbf{x} \, \Vert \, h_{\mathbf{\Theta}}( \mathbf{c} \, \Vert \, \mathbf{n})
        - **attention_on_cat_and_numerical_feats** self attention on the text features
            .. math::
                \mathbf{m} = \alpha_{x,x}\mathbf{W}_x\mathbf{x} + \alpha_{x,c}\mathbf{W}_c\mathbf{c} + \alpha_{x,n}\mathbf{W}_n\mathbf{n}
          where :math:`\mathbf{W}_x` is of shape :obj:`(out_dim, text_feat_dim)`,
          :math:`\mathbf{W}_c` is of shape :obj:`(out_dim, cat_feat_dim)`,
          :math:`\mathbf{W}_n` is of shape :obj:`(out_dim, num_feat_dim)`, and the attention coefficients :math:`\alpha_{i,j}` are computed as
            .. math::
                \alpha_{i,j} =
                \frac{
                \exp\left(\mathrm{LeakyReLU}\left(\mathbf{a}^{\top}
                [\mathbf{W}_i\mathbf{x}_i \, \Vert \, \mathbf{W}_j\mathbf{x}_j]
                \right)\right)}
                {\sum_{k \in \{ x, c, n \}}
                \exp\left(\mathrm{LeakyReLU}\left(\mathbf{a}^{\top}
                [\mathbf{W}_i\mathbf{x}_i \, \Vert \, \mathbf{W}_k\mathbf{x}_k]
                \right)\right)}.
        - **gating_on_cat_and_num_feats_then_sum** sum of features gated by text features. Inspired by the gating mechanism introduced in `Integrating Multimodal Information in Large Pretrained Transformers <https://www.aclweb.org/anthology/2020.acl-main.214.pdf>`_
            .. math::
                \mathbf{m}= \mathbf{x} + \alpha\mathbf{h}
            .. math::
                \mathbf{h} = \mathbf{g_c} \odot (\mathbf{W}_c\mathbf{c}) + \mathbf{g_n} \odot (\mathbf{W}_n\mathbf{n}) + b_h
            .. math::
                \alpha = \mathrm{min}( \frac{\| \mathbf{x} \|_2}{\| \mathbf{h} \|_2}*\beta, 1)
          where :math:`\beta` is a hyperparamter, :math:`\mathbf{W}_c` is of shape :obj:`(out_dim, cat_feat_dim)`,
          :math:`\mathbf{W}_n` is of shape :obj:`(out_dim, num_feat_dim)`. and the gating vector :math:`\mathbf{g}_i` with activation function :math:`R` is defined as
            .. math::
                \mathbf{g}_i = R(\mathbf{W}_{gi}[\mathbf{i} \, \Vert \, \mathbf{x}]+ b_i)
          where :math:`\mathbf{W}_{gi}` is of shape :obj:`(out_dim, i_feat_dim + text_feat_dim)`
        - **weighted_feature_sum_on_transformer_cat_and_numerical_feats**
            .. math::
                \mathbf{m} = \mathbf{x} + \mathbf{W}_{c'} \odot \mathbf{W}_c \mathbf{c} + \mathbf{W}_{n'} \odot \mathbf{W}_n \mathbf{t}
       Parameters:
           tabular_config (:class:`~multimodal_config.TabularConfig`):
               Tabular model configuration class with all the parameters of the model.
       """
    def __init__(self, tabular_config):
        super().__init__()
        self.combine_feat_method = tabular_config.combine_feat_method
        self.cat_feat_dim = tabular_config.cat_feat_dim
        self.numerical_feat_dim = tabular_config.numerical_feat_dim
        self.num_labels = tabular_config.num_labels
        self.numerical_bn = tabular_config.numerical_bn
        self.mlp_act = tabular_config.mlp_act
        self.mlp_dropout = tabular_config.mlp_dropout
        self.mlp_division = tabular_config.mlp_division
        self.text_out_dim = tabular_config.text_feat_dim
        self.tabular_config = tabular_config

        if self.numerical_bn and self.numerical_feat_dim > 0:
            self.num_bn = nn.BatchNorm1d(self.numerical_feat_dim)
        else:
            self.num_bn = None

        if self.combine_feat_method == 'text_only':
            self.final_out_dim = self.text_out_dim
        elif self.combine_feat_method == 'concat':
            self.final_out_dim = self.text_out_dim + self.cat_feat_dim \
                           + self.numerical_feat_dim
        elif self.combine_feat_method == 'mlp_on_categorical_then_concat':
            assert self.cat_feat_dim != 0, 'dimension of cat feats should not be 0'
            # reduce dim of categorical features to same of num dim or text dim if necessary
            output_dim = min(self.text_out_dim,
                             max(self.numerical_feat_dim, self.cat_feat_dim // (self.mlp_division // 2)))
            dims = calc_mlp_dims(
                self.cat_feat_dim,
                self.mlp_division,
                output_dim
            )
            self.cat_mlp = MLP(
                self.cat_feat_dim,
                output_dim,
                act=self.mlp_act,
                num_hidden_lyr=len(dims),
                dropout_prob=self.mlp_dropout,
                hidden_channels=dims,
                return_layer_outs=False,
                bn=True
            )
            self.final_out_dim = self.text_out_dim + output_dim + self.numerical_feat_dim
        elif self.combine_feat_method == 'mlp_on_concatenated_cat_and_numerical_feats_then_concat':
            assert self.cat_feat_dim != 0, 'dimension of cat feats should not be 0'
            assert self.numerical_feat_dim != 0, 'dimension of numerical feats should not be 0'
            output_dim = min(self.numerical_feat_dim, self.cat_feat_dim, self.text_out_dim)
            in_dim = self.cat_feat_dim + self.numerical_feat_dim
            dims = calc_mlp_dims(
                in_dim,
                self.mlp_division,
                output_dim
            )
            self.cat_and_numerical_mlp = MLP(
                in_dim,
                output_dim,
                act=self.mlp_act,
                num_hidden_lyr=len(dims),
                dropout_prob=self.mlp_dropout,
                hidden_channels=dims,
                return_layer_outs=False,
                bn=True
            )
            self.final_out_dim = self.text_out_dim + output_dim
        elif self.combine_feat_method == 'individual_mlps_on_cat_and_numerical_feats_then_concat':
            output_dim_cat = 0
            if self.cat_feat_dim > 0:
                output_dim_cat = max(self.cat_feat_dim // (self.mlp_division // 2),
                                     self.numerical_feat_dim)
                dims = calc_mlp_dims(
                    self.cat_feat_dim,
                    self.mlp_division,
                    output_dim_cat)
                self.cat_mlp = MLP(
                    self.cat_feat_dim,
                    output_dim_cat,
                    act=self.mlp_act,
                    num_hidden_lyr=len(dims),
                    dropout_prob=self.mlp_dropout,
                    hidden_channels=dims,
                    return_layer_outs=False,
                    bn=True)

            output_dim_num = 0
            if self.numerical_feat_dim > 0:
                output_dim_num = self.numerical_feat_dim // (self.mlp_division // 2)
                self.num_mlp = MLP(
                    self.numerical_feat_dim,
                    output_dim_num,
                    act=self.mlp_act,
                    dropout_prob=self.mlp_dropout,
                    num_hidden_lyr=1,
                    return_layer_outs=False,
                    bn=True)
            self.final_out_dim = self.text_out_dim + output_dim_num + output_dim_cat
        elif self.combine_feat_method == 'weighted_feature_sum_on_transformer_cat_and_numerical_feats':
            assert self.cat_feat_dim + self.numerical_feat_dim != 0, 'should have some non text features'
            if self.cat_feat_dim > 0:
                output_dim_cat = self.text_out_dim
                if self.cat_feat_dim > self.text_out_dim:
                    dims = calc_mlp_dims(
                        self.cat_feat_dim,
                        division=self.mlp_division,
                        output_dim=output_dim_cat)
                    self.cat_layer = MLP(
                        self.cat_feat_dim,
                        output_dim_cat,
                        act=self.mlp_act,
                        num_hidden_lyr=len(dims),
                        dropout_prob=self.mlp_dropout,
                        hidden_channels=dims,
                        return_layer_outs=False,
                        bn=True)
                else:
                    self.cat_layer = nn.Linear(self.cat_feat_dim, output_dim_cat)
                self.dropout_cat = nn.Dropout(self.mlp_dropout)
                self.weight_cat = nn.Parameter(torch.rand(output_dim_cat))
            if self.numerical_feat_dim > 0:
                output_dim_num = self.text_out_dim
                if self.numerical_feat_dim > self.text_out_dim:
                    dims = calc_mlp_dims(
                        self.numerical_feat_dim,
                        division=self.mlp_division,
                        output_dim=output_dim_num)
                    self.num_layer = MLP(
                        self.numerical_feat_dim,
                        output_dim_num,
                        act=self.mlp_act,
                        num_hidden_lyr=len(dims),
                        dropout_prob=self.mlp_dropout,
                        hidden_channels=dims,
                        return_layer_outs=False,
                        bn=True)
                else:
                    self.num_layer = nn.Linear(self.numerical_feat_dim,
                                               output_dim_num)
                self.dropout_num = nn.Dropout(self.mlp_dropout)
                self.weight_num = nn.Parameter(torch.rand(output_dim_num))

            self.act_func = create_act(self.mlp_act)
            self.layer_norm = nn.LayerNorm(self.text_out_dim)
            self.final_dropout = nn.Dropout(tabular_config.hidden_dropout_prob)
            self.final_out_dim = self.text_out_dim

        elif self.combine_feat_method == 'attention_on_cat_and_numerical_feats':
            assert self.cat_feat_dim + self.numerical_feat_dim != 0, \
                'should have some non-text features for this method'

            output_dim = self.text_out_dim
            if self.cat_feat_dim > 0:
                if self.cat_feat_dim > self.text_out_dim:
                    output_dim_cat = self.text_out_dim
                    dims = calc_mlp_dims(
                        self.cat_feat_dim,
                        division=self.mlp_division,
                        output_dim=output_dim_cat)
                    self.cat_mlp = MLP(
                        self.cat_feat_dim,
                        output_dim_cat,
                        num_hidden_lyr=len(dims),
                        dropout_prob=self.mlp_dropout,
                        return_layer_outs=False,
                        hidden_channels=dims,
                        bn=True)
                else:
                    output_dim_cat = self.cat_feat_dim
                self.weight_cat = nn.Parameter(torch.rand((output_dim_cat,
                                                           output_dim)))
                self.bias_cat = nn.Parameter(torch.zeros(output_dim))

            if self.numerical_feat_dim > 0:
                if self.numerical_feat_dim > self.text_out_dim:
                    output_dim_num = self.text_out_dim
                    dims = calc_mlp_dims(
                        self.numerical_feat_dim,
                        division=self.mlp_division,
                        output_dim=output_dim_num)
                    self.cat_mlp = MLP(
                        self.numerical_feat_dim,
                        output_dim_num,
                        num_hidden_lyr=len(dims),
                        dropout_prob=self.mlp_dropout,
                        return_layer_outs=False,
                        hidden_channels=dims,
                        bn=True)
                else:
                    output_dim_num = self.numerical_feat_dim
                self.weight_num = nn.Parameter(torch.rand((output_dim_num,
                                                            output_dim)))
                self.bias_num = nn.Parameter(torch.zeros(output_dim))

            self.weight_transformer = nn.Parameter(torch.rand(self.text_out_dim,
                                                       output_dim))
            self.weight_a = nn.Parameter(torch.rand((1, output_dim + output_dim)))
            self.bias_transformer = nn.Parameter(torch.rand(output_dim))
            self.bias = nn.Parameter(torch.zeros(output_dim))
            self.negative_slope = 0.2
            self.final_out_dim = output_dim
            self.__reset_parameters()
        elif self.combine_feat_method == 'gating_on_cat_and_num_feats_then_sum':
            self.act_func = create_act(self.mlp_act)
            if self.cat_feat_dim > 0:
                if self.cat_feat_dim > self.text_out_dim:
                    dims = calc_mlp_dims(
                        self.numerical_feat_dim,
                        division=self.mlp_division,
                        output_dim=self.text_out_dim)
                    self.cat_layer = MLP(
                        self.cat_feat_dim,
                        self.text_out_dim,
                        act=self.mlp_act,
                        num_hidden_lyr=len(dims),
                        dropout_prob=self.mlp_dropout,
                        hidden_channels=dims,
                        return_layer_outs=False,
                        bn=True)
                self.g_cat_layer = nn.Linear(self.text_out_dim + min(self.text_out_dim, self.cat_feat_dim),
                                             self.text_out_dim)
                self.dropout_cat = nn.Dropout(self.mlp_dropout)
                self.h_cat_layer = nn.Linear(min(self.text_out_dim, self.cat_feat_dim), self.text_out_dim, bias=False)
            if self.numerical_feat_dim > 0:
                if self.numerical_feat_dim > self.text_out_dim:
                    dims = calc_mlp_dims(
                        self.numerical_feat_dim,
                        division=self.mlp_division,
                        output_dim=self.text_out_dim)
                    self.num_layer = MLP(
                        self.numerical_feat_dim,
                        self.text_out_dim,
                        act=self.mlp_act,
                        num_hidden_lyr=len(dims),
                        dropout_prob=self.mlp_dropout,
                        hidden_channels=dims,
                        return_layer_outs=False,
                        bn=True)
                self.g_num_layer = nn.Linear(min(self.numerical_feat_dim, self.text_out_dim) + self.text_out_dim,
                                             self.text_out_dim)
                self.dropout_num = nn.Dropout(self.mlp_dropout)
                self.h_num_layer = nn.Linear(min(self.text_out_dim, self.numerical_feat_dim),
                                             self.text_out_dim, bias=False)
            self.h_bias = nn.Parameter(torch.zeros(self.text_out_dim))
            self.layer_norm = nn.LayerNorm(self.text_out_dim)
            self.final_out_dim = self.text_out_dim
        else:
            raise ValueError(f'combine_feat_method {self.combine_feat_method} '
                             f'not implemented')

    def forward(self, text_feats, cat_feats=None, numerical_feats=None):
        """
        Args:
            text_feats (:obj:`torch.FloatTensor` of shape :obj:`(batch_size, text_out_dim)`):
                The tensor of text features. This is assumed to be the output from a HuggingFace transformer model
            cat_feats (:obj:`torch.FloatTensor` of shape :obj:`(batch_size, cat_feat_dim)`, `optional`, defaults to :obj:`None`)):
                The tensor of categorical features
            numerical_feats (:obj:`torch.FloatTensor` of shape :obj:`(batch_size, numerical_feat_dim)`, `optional`, defaults to :obj:`None`):
                The tensor of numerical features
        Returns:
            :obj:`torch.FloatTensor` of shape :obj:`(batch_size, final_out_dim)`:
                A tensor representing the combined features
        """
        if cat_feats is None:
            cat_feats = torch.zeros((text_feats.shape[0], 0)).to(text_feats.device)
        if numerical_feats is None:
            numerical_feats = torch.zeros((text_feats.shape[0], 0)).to(text_feats.device)

        if self.numerical_bn and self.numerical_feat_dim != 0:
            numerical_feats = self.num_bn(numerical_feats)

        if self.combine_feat_method == 'text_only':
            combined_feats = text_feats
        if self.combine_feat_method == 'concat':
            combined_feats = torch.cat((text_feats, cat_feats, numerical_feats),
                                       dim=1)
        elif self.combine_feat_method == 'mlp_on_categorical_then_concat':
            cat_feats = self.cat_mlp(cat_feats)
            combined_feats = torch.cat((text_feats, cat_feats, numerical_feats), dim=1)
        elif self.combine_feat_method == 'mlp_on_concatenated_cat_and_numerical_feats_then_concat':
            tabular_feats = torch.cat((cat_feats, numerical_feats), dim=1)
            tabular_feats = self.cat_and_numerical_mlp(tabular_feats)
            combined_feats = torch.cat((text_feats, tabular_feats), dim=1)
        elif self.combine_feat_method == 'individual_mlps_on_cat_and_numerical_feats_then_concat':
            if cat_feats.shape[1] != 0:
                cat_feats = self.cat_mlp(cat_feats)
            if numerical_feats.shape[1] != 0:
                numerical_feats = self.num_mlp(numerical_feats)
            combined_feats = torch.cat((text_feats, cat_feats, numerical_feats), dim=1)
        elif self.combine_feat_method == 'weighted_feature_sum_on_transformer_cat_and_numerical_feats':
            if cat_feats.shape[1] != 0:
                cat_feats = self.dropout_cat(self.cat_layer(cat_feats))
                cat_feats = self.weight_cat.expand_as(cat_feats) * cat_feats
            else:
                cat_feats = 0

            if numerical_feats.shape[1] != 0:
                numerical_feats = self.dropout_num(self.num_layer(numerical_feats))
                numerical_feats = self.weight_num.expand_as(numerical_feats) * numerical_feats
            else:
                numerical_feats = 0
            combined_feats = text_feats + cat_feats + numerical_feats
        elif self.combine_feat_method == 'attention_on_cat_and_numerical_feats':
            # attention keyed by transformer text features
            w_text = torch.mm(text_feats, self.weight_transformer)
            g_text = (torch.cat([w_text, w_text], dim=-1) * self.weight_a).sum(dim=1).unsqueeze(0).T

            if cat_feats.shape[1] != 0:
                if self.cat_feat_dim > self.text_out_dim:
                    cat_feats = self.cat_mlp(cat_feats)
                w_cat = torch.mm(cat_feats, self.weight_cat)
                g_cat = (torch.cat([w_text, w_cat], dim=-1) * self.weight_a).sum(dim=1).unsqueeze(0).T
            else:
                w_cat = None
                g_cat = torch.zeros(0, device=g_text.device)

            if numerical_feats.shape[1] != 0:
                if self.numerical_feat_dim > self.text_out_dim:
                    numerical_feats = self.num_mlp(numerical_feats)
                w_num = torch.mm(numerical_feats, self.weight_num)
                g_num = (torch.cat([w_text, w_cat], dim=-1) * self.weight_a).sum(dim=1).unsqueeze(0).T
            else:
                w_num = None
                g_num = torch.zeros(0, device=g_text.device)

            alpha = torch.cat([g_text, g_cat, g_num], dim=1)  # N by 3
            alpha = F.leaky_relu(alpha, 0.02)
            alpha = F.softmax(alpha, -1)
            stack_tensors = [tensor for tensor in [w_text, w_cat, w_num]
                             if tensor is not None]
            combined = torch.stack(stack_tensors, dim=1)  # N by 3 by final_out_dim
            outputs_w_attention = alpha[:, :, None] * combined
            combined_feats = outputs_w_attention.sum(dim=1)  # N by final_out_dim
        elif self.combine_feat_method == 'gating_on_cat_and_num_feats_then_sum':
            # assumes shifting of features relative to text features and that text features are the most important
            if cat_feats.shape[1] != 0:
                if self.cat_feat_dim > self.text_out_dim:
                    cat_feats = self.cat_layer(cat_feats)
                g_cat = self.dropout_cat(self.act_func(self.g_cat_layer(torch.cat([text_feats, cat_feats], dim=1))))
                g_mult_cat = g_cat * self.h_cat_layer(cat_feats)
            else:
                g_mult_cat = 0

            if numerical_feats.shape[1] != 0:
                if self.numerical_feat_dim > self.text_out_dim:
                    numerical_feats = self.num_layer(numerical_feats)
                g_num = self.dropout_num(self.act_func(self.g_num_layer(torch.cat([text_feats, numerical_feats], dim=1))))
                g_mult_num = g_num * self.h_num_layer(numerical_feats)
            else:
                g_mult_num = 0

            H = g_mult_cat + g_mult_num + self.h_bias
            norm = torch.norm(text_feats, dim=1) / torch.norm(H, dim=1)
            alpha = torch.clamp(norm * self.tabular_config.gating_beta, min=0, max=1)
            combined_feats = text_feats + alpha[:, None] * H

        return combined_feats

    def __reset_parameters(self):
        glorot(self.weight_a)
        if hasattr(self, 'weight_cat'):
            glorot(self.weight_cat)
            zeros(self.bias_cat)
        if hasattr(self, 'weight_num'):
            glorot(self.weight_num)
            zeros(self.bias_num)
        glorot(self.weight_transformer)
        zeros(self.bias_transformer)

# %%
class DistilBertWithTabular(DistilBertForSequenceClassification):
    """
    DistilBert Model transformer with a sequence classification/regression head as well as
    a TabularFeatCombiner module to combine categorical and numerical features
    with the Roberta pooled output
    Parameters:
        hf_model_config (:class:`~transformers.DistilBertConfig`):
            Model configuration class with all the parameters of the model.
            This object must also have a tabular_config member variable that is a
            :obj:`TabularConfig` instance specifying the configs for :obj:`TabularFeatCombiner`
    """
    def __init__(self, hf_model_config):
        super().__init__(hf_model_config)
        tabular_config = hf_model_config.tabular_config
        if type(tabular_config) is dict:  # when loading from saved model
            tabular_config = TabularConfig(**tabular_config)
        else:
            self.config.tabular_config = tabular_config.__dict__

        tabular_config.text_feat_dim = hf_model_config.hidden_size
        tabular_config.hidden_dropout_prob = hf_model_config.seq_classif_dropout
        self.tabular_combiner = TabularFeatCombiner(tabular_config)
        self.num_labels = tabular_config.num_labels
        combined_feat_dim = self.tabular_combiner.final_out_dim
        if tabular_config.use_simple_classifier:
            self.tabular_classifier = nn.Linear(combined_feat_dim,
                                                tabular_config.num_labels)
        else:
            dims = calc_mlp_dims(combined_feat_dim,
                                 division=tabular_config.mlp_division,
                                 output_dim=tabular_config.num_labels)
            self.tabular_classifier = MLP(combined_feat_dim,
                                          tabular_config.num_labels,
                                          num_hidden_lyr=len(dims),
                                          dropout_prob=tabular_config.mlp_dropout,
                                          hidden_channels=dims,
                                          bn=True)

    # @add_start_docstrings_to_callable(DISTILBERT_INPUTS_DOCSTRING.format("(batch_size, sequence_length)"))
    def forward(
        self,
        input_ids=None,
        attention_mask=None,
        head_mask=None,
        inputs_embeds=None,
        labels=None,
        output_attentions=None,
        output_hidden_states=None,
        class_weights=None,
        cat_feats=None,
        numerical_feats=None
    ):
        r"""
        class_weights (:obj:`torch.FloatTensor` of shape :obj:`(tabular_config.num_labels,)`,`optional`, defaults to :obj:`None`):
            Class weights to be used for cross entropy loss function for classification task
        labels (:obj:`torch.LongTensor` of shape :obj:`(batch_size,)`, `optional`, defaults to :obj:`None`):
            Labels for computing the sequence classification/regression loss.
            Indices should be in :obj:`[0, ..., config.num_labels - 1]`.
            If :obj:`tabular_config.num_labels == 1` a regression loss is computed (Mean-Square loss),
            If :obj:`tabular_config.num_labels > 1` a classification loss is computed (Cross-Entropy).
        cat_feats (:obj:`torch.FloatTensor` of shape :obj:`(batch_size, tabular_config.cat_feat_dim)`,`optional`, defaults to :obj:`None`):
            Categorical features to be passed in to the TabularFeatCombiner
        numerical_feats (:obj:`torch.FloatTensor` of shape :obj:`(batch_size, tabular_config.numerical_feat_dim)`,`optional`, defaults to :obj:`None`):
            Numerical features to be passed in to the TabularFeatCombiner
    Returns:
        :obj:`tuple` comprising various elements depending on configuration and inputs:
        loss (:obj:`torch.FloatTensor` of shape :obj:`(1,)`, `optional`, returned when :obj:`label` is provided):
            Classification (or regression if tabular_config.num_labels==1) loss.
        logits (:obj:`torch.FloatTensor` of shape :obj:`(batch_size, tabular_config.num_labels)`):
            Classification (or regression if tabular_config.num_labels==1) scores (before SoftMax).
        classifier_layer_outputs(:obj:`list` of :obj:`torch.FloatTensor`):
            The outputs of each layer of the final classification layers. The 0th index of this list is the
            combining module's output
        """

        distilbert_output = self.distilbert(
            input_ids,
            attention_mask=attention_mask,
            head_mask=head_mask,
            inputs_embeds=inputs_embeds,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
        )
        hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
        pooled_output = hidden_state[:, 0]  # (bs, dim)
        pooled_output = self.pre_classifier(pooled_output)  # (bs, dim)
        pooled_output = nn.ReLU()(pooled_output)  # (bs, dim)
        text_feats = self.dropout(pooled_output)
        combined_feats = self.tabular_combiner(text_feats,
                                               cat_feats,
                                               numerical_feats)
        loss, logits, classifier_layer_outputs = hf_loss_func(combined_feats,
                                                              self.tabular_classifier,
                                                              labels,
                                                              self.num_labels,
                                                              class_weights)
        return loss, logits, classifier_layer_outputs

# %%
from transformers import AutoConfig,DistilBertConfig

# %%
config = AutoConfig.from_pretrained(
        'distilbert-base-uncased'
    )

tabular_config = TabularConfig(num_labels=num_labels,
                               cat_feat_dim=0,
                               numerical_feat_dim=5,
                               combine_feat_method='concat',
                               column_info=column_info_dict,
                               task='regression')

config.tabular_config = tabular_config

# %%
model = DistilBertWithTabular.from_pretrained(
        'distilbert-base-uncased',
        config=config
    )
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertWithTabular: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertWithTabular from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertWithTabular from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertWithTabular were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['tabular_classifier.weight', 'tabular_classifier.bias', 'tabular_combiner.num_bn.weight', 'pre_classifier.bias', 'tabular_combiner.num_bn.bias', 'tabular_combiner.num_bn.running_mean', 'classifier.weight', 'tabular_combiner.num_bn.running_var', 'classifier.bias', 'tabular_combiner.num_bn.num_batches_tracked', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import csv
class DictWriter:
    
    def __init__(self,file_path,field_names):
        self.field_names = field_names
        self.file_path = file_path
        self.create_file() #Crerate file if it doesnt exist.
        
    def create_file(self):
        if not os.path.exists(self.file_path):
            print('creating file')
            f = open(self.file_path, 'w')
            w = csv.DictWriter(f, field_names)
            w.writeheader()
            f.close()
        else:
            print('file already exist. Will append rows to it.')
            
    def add_rows(self,rows):  
        with open(self.file_path, 'a') as f:
            w = csv.DictWriter(f,self.field_names)
            for r in rows:    
                w.writerow(r)

# %%
epochs = 15
num_evals = 20
patience = 2 if DEBUG else 30
callbacks=[EarlyStoppingCallback(early_stopping_patience=patience)]
eval_steps = 50 if DEBUG else 100


hparams = {'batch_size' : [8,16,32],
           'learning_rate' : [1e-5, 2e-5, 3e-5, 5e-5, 7e-5, 9e-5],
           'weight_decay' : [0.1,0.01],
           'repeats': range(1)}

combs = list(product(*[range(len(i)) for i in list(hparams.values())]))
scores = np.zeros([len(i) for i in list(hparams.values())])

#trials_df_rows = []

field_names = list(hparams.keys()) + ['score']
dw = DictWriter(TRIALS_DF_PATH,field_names)

currernt_trials_df = pd.read_csv(TRIALS_DF_PATH) #This can be empty or not.
done_trials = currernt_trials_df.drop('score',axis=1).to_dict(orient='records') #empty list or not
best_score = min(float('inf'),currernt_trials_df['score'].min())

print(f'current best val score = {best_score}')

for idx,comb_indexes in enumerate(combs):
    comb_values = {name:val[idx] for name,val,idx in zip(hparams.keys(),hparams.values(),comb_indexes)}
    
    if comb_values not in done_trials: #Check if trial alrready exists. If it does, skip.
        print('training with following hparams:')
        pprint(comb_values)

        training_args = TrainingArguments(output_dir=f"{MODEL_NAME}-{TARGET_COL}",
                                          per_device_train_batch_size = comb_values['batch_size'],
                                          learning_rate=comb_values['learning_rate'],
                                          weight_decay=comb_values['weight_decay'],
                                          seed = 42,
                                          fp16=True,
                                          per_device_eval_batch_size = 16,
                                          warmup_ratio=0.06,
                                          num_train_epochs = epochs,
                                          evaluation_strategy = "steps",
                                          save_strategy = "steps",
                                          load_best_model_at_end=True,
                                          eval_steps = eval_steps,
                                          save_steps = eval_steps,
                                          save_total_limit = 1,
                                          log_level = 'error',
                                          disable_tqdm = True

                                        )

        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=train_dataset,
            eval_dataset=val_dataset,
            callbacks = callbacks
        )
        


        trainer.train()

        score = trainer.evaluate()['eval_loss']

        scores[tuple(comb_indexes)] = score #outdated

        comb_values['score'] = score

        dw.add_rows([comb_values]) #Append to dataframe

        #trials_df_rows.append(comb_values)

        if score<best_score:
            print(f'got a better model, with score {np.round(score,4)} saving...')
            best_score = score
            trainer.save_model(FINAL_MODEL_PATH)
            
            print('saved')
    else:
        print('skipping trial because already exists')


#trials_df = pd.DataFrame(trials_df_rows)
#trials_df.to_csv(f'models/{MODEL_FOLDER}/hparams_trials.csv',index=False)
# Out:
# creating file
# current best val score = inf
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 1e-05, 'repeats': 0, 'weight_decay': 0.1}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 189.909423828125, 'eval_runtime': 10.2389, 'eval_samples_per_second': 171.308, 'eval_steps_per_second': 10.743, 'epoch': 0.1}
# {'eval_loss': 142.33213806152344, 'eval_runtime': 10.582, 'eval_samples_per_second': 165.754, 'eval_steps_per_second': 10.395, 'epoch': 0.2}
# {'eval_loss': 99.93277740478516, 'eval_runtime': 10.8579, 'eval_samples_per_second': 161.541, 'eval_steps_per_second': 10.131, 'epoch': 0.29}
# {'eval_loss': 73.40424346923828, 'eval_runtime': 11.3223, 'eval_samples_per_second': 154.916, 'eval_steps_per_second': 9.715, 'epoch': 0.39}
# {'loss': 156.5629, 'learning_rate': 5.357917570498916e-06, 'epoch': 0.49}
# {'eval_loss': 52.16685104370117, 'eval_runtime': 11.8013, 'eval_samples_per_second': 148.628, 'eval_steps_per_second': 9.321, 'epoch': 0.49}
# {'eval_loss': 33.2209358215332, 'eval_runtime': 11.8498, 'eval_samples_per_second': 148.019, 'eval_steps_per_second': 9.283, 'epoch': 0.59}
# {'eval_loss': 18.63239860534668, 'eval_runtime': 11.6166, 'eval_samples_per_second': 150.99, 'eval_steps_per_second': 9.469, 'epoch': 0.68}
# {'eval_loss': 12.918280601501465, 'eval_runtime': 11.7147, 'eval_samples_per_second': 149.727, 'eval_steps_per_second': 9.39, 'epoch': 0.78}
# {'eval_loss': 13.634228706359863, 'eval_runtime': 11.7555, 'eval_samples_per_second': 149.207, 'eval_steps_per_second': 9.357, 'epoch': 0.88}
# {'loss': 25.6011, 'learning_rate': 9.950131597174125e-06, 'epoch': 0.98}
# {'eval_loss': 14.996318817138672, 'eval_runtime': 11.8099, 'eval_samples_per_second': 148.52, 'eval_steps_per_second': 9.314, 'epoch': 0.98}
# {'eval_loss': 11.694005012512207, 'eval_runtime': 11.7993, 'eval_samples_per_second': 148.652, 'eval_steps_per_second': 9.323, 'epoch': 1.07}
# {'eval_loss': 7.745199203491211, 'eval_runtime': 11.8586, 'eval_samples_per_second': 147.91, 'eval_steps_per_second': 9.276, 'epoch': 1.17}
# {'eval_loss': 8.332188606262207, 'eval_runtime': 11.8114, 'eval_samples_per_second': 148.5, 'eval_steps_per_second': 9.313, 'epoch': 1.27}
# {'eval_loss': 7.909019947052002, 'eval_runtime': 11.7809, 'eval_samples_per_second': 148.885, 'eval_steps_per_second': 9.337, 'epoch': 1.37}
# {'loss': 6.5266, 'learning_rate': 9.603823244216652e-06, 'epoch': 1.46}
# {'eval_loss': 6.9963274002075195, 'eval_runtime': 11.7714, 'eval_samples_per_second': 149.005, 'eval_steps_per_second': 9.345, 'epoch': 1.46}
# {'eval_loss': 9.111039161682129, 'eval_runtime': 11.8145, 'eval_samples_per_second': 148.461, 'eval_steps_per_second': 9.311, 'epoch': 1.56}
# {'eval_loss': 7.276303768157959, 'eval_runtime': 11.8507, 'eval_samples_per_second': 148.008, 'eval_steps_per_second': 9.282, 'epoch': 1.66}
# {'eval_loss': 7.1449456214904785, 'eval_runtime': 11.8558, 'eval_samples_per_second': 147.945, 'eval_steps_per_second': 9.278, 'epoch': 1.76}
# {'eval_loss': 6.352295398712158, 'eval_runtime': 11.8993, 'eval_samples_per_second': 147.404, 'eval_steps_per_second': 9.244, 'epoch': 1.86}
# {'loss': 5.1751, 'learning_rate': 9.25751489125918e-06, 'epoch': 1.95}
# {'eval_loss': 5.918769359588623, 'eval_runtime': 11.8618, 'eval_samples_per_second': 147.87, 'eval_steps_per_second': 9.273, 'epoch': 1.95}
# {'eval_loss': 6.068140983581543, 'eval_runtime': 11.8812, 'eval_samples_per_second': 147.628, 'eval_steps_per_second': 9.258, 'epoch': 2.05}
# {'eval_loss': 5.703686714172363, 'eval_runtime': 11.8148, 'eval_samples_per_second': 148.458, 'eval_steps_per_second': 9.31, 'epoch': 2.15}
# {'eval_loss': 6.177711009979248, 'eval_runtime': 11.7581, 'eval_samples_per_second': 149.173, 'eval_steps_per_second': 9.355, 'epoch': 2.25}
# {'eval_loss': 6.21095085144043, 'eval_runtime': 11.8421, 'eval_samples_per_second': 148.116, 'eval_steps_per_second': 9.289, 'epoch': 2.34}
# {'loss': 4.288, 'learning_rate': 8.911206538301705e-06, 'epoch': 2.44}
# {'eval_loss': 5.831523418426514, 'eval_runtime': 11.9051, 'eval_samples_per_second': 147.331, 'eval_steps_per_second': 9.24, 'epoch': 2.44}
# {'eval_loss': 7.400740146636963, 'eval_runtime': 11.815, 'eval_samples_per_second': 148.456, 'eval_steps_per_second': 9.31, 'epoch': 2.54}
# {'eval_loss': 6.392859935760498, 'eval_runtime': 11.7637, 'eval_samples_per_second': 149.103, 'eval_steps_per_second': 9.351, 'epoch': 2.64}
# {'eval_loss': 6.536906719207764, 'eval_runtime': 11.8221, 'eval_samples_per_second': 148.366, 'eval_steps_per_second': 9.305, 'epoch': 2.73}
# {'eval_loss': 8.183938026428223, 'eval_runtime': 11.853, 'eval_samples_per_second': 147.979, 'eval_steps_per_second': 9.28, 'epoch': 2.83}
# {'loss': 4.1417, 'learning_rate': 8.564898185344232e-06, 'epoch': 2.93}
# {'eval_loss': 7.0942769050598145, 'eval_runtime': 11.8818, 'eval_samples_per_second': 147.621, 'eval_steps_per_second': 9.258, 'epoch': 2.93}
# {'eval_loss': 6.301211833953857, 'eval_runtime': 11.8969, 'eval_samples_per_second': 147.433, 'eval_steps_per_second': 9.246, 'epoch': 3.03}
# {'eval_loss': 6.506949424743652, 'eval_runtime': 11.878, 'eval_samples_per_second': 147.669, 'eval_steps_per_second': 9.261, 'epoch': 3.12}
# {'eval_loss': 9.05278205871582, 'eval_runtime': 11.8859, 'eval_samples_per_second': 147.57, 'eval_steps_per_second': 9.255, 'epoch': 3.22}
# {'eval_loss': 6.84686279296875, 'eval_runtime': 11.8841, 'eval_samples_per_second': 147.592, 'eval_steps_per_second': 9.256, 'epoch': 3.32}
# {'loss': 3.4301, 'learning_rate': 8.218589832386758e-06, 'epoch': 3.42}
# {'eval_loss': 7.750691890716553, 'eval_runtime': 11.8673, 'eval_samples_per_second': 147.802, 'eval_steps_per_second': 9.269, 'epoch': 3.42}
# {'eval_loss': 6.223961353302002, 'eval_runtime': 11.8888, 'eval_samples_per_second': 147.534, 'eval_steps_per_second': 9.252, 'epoch': 3.52}
# {'eval_loss': 5.967785358428955, 'eval_runtime': 11.9088, 'eval_samples_per_second': 147.287, 'eval_steps_per_second': 9.237, 'epoch': 3.61}
# {'eval_loss': 6.440571308135986, 'eval_runtime': 11.9277, 'eval_samples_per_second': 147.052, 'eval_steps_per_second': 9.222, 'epoch': 3.71}
# {'eval_loss': 6.003212928771973, 'eval_runtime': 11.8345, 'eval_samples_per_second': 148.211, 'eval_steps_per_second': 9.295, 'epoch': 3.81}
# {'loss': 3.2797, 'learning_rate': 7.872281479429285e-06, 'epoch': 3.91}
# {'eval_loss': 6.863575458526611, 'eval_runtime': 11.8852, 'eval_samples_per_second': 147.579, 'eval_steps_per_second': 9.255, 'epoch': 3.91}
# {'eval_loss': 7.701869010925293, 'eval_runtime': 11.92, 'eval_samples_per_second': 147.148, 'eval_steps_per_second': 9.228, 'epoch': 4.0}
# {'eval_loss': 7.533651828765869, 'eval_runtime': 11.9087, 'eval_samples_per_second': 147.288, 'eval_steps_per_second': 9.237, 'epoch': 4.1}
# {'eval_loss': 6.58931827545166, 'eval_runtime': 11.8999, 'eval_samples_per_second': 147.396, 'eval_steps_per_second': 9.244, 'epoch': 4.2}
# {'eval_loss': 5.977237701416016, 'eval_runtime': 11.9058, 'eval_samples_per_second': 147.323, 'eval_steps_per_second': 9.239, 'epoch': 4.3}
# {'loss': 2.7677, 'learning_rate': 7.5266657431777255e-06, 'epoch': 4.39}
# {'eval_loss': 7.499351978302002, 'eval_runtime': 11.9224, 'eval_samples_per_second': 147.118, 'eval_steps_per_second': 9.226, 'epoch': 4.39}
# {'eval_loss': 6.377643585205078, 'eval_runtime': 11.8854, 'eval_samples_per_second': 147.576, 'eval_steps_per_second': 9.255, 'epoch': 4.49}
# {'eval_loss': 6.0319037437438965, 'eval_runtime': 11.9138, 'eval_samples_per_second': 147.224, 'eval_steps_per_second': 9.233, 'epoch': 4.59}
# {'eval_loss': 7.868436813354492, 'eval_runtime': 11.8929, 'eval_samples_per_second': 147.483, 'eval_steps_per_second': 9.249, 'epoch': 4.69}
# {'eval_loss': 6.5885186195373535, 'eval_runtime': 11.893, 'eval_samples_per_second': 147.482, 'eval_steps_per_second': 9.249, 'epoch': 4.79}
# {'loss': 2.5978, 'learning_rate': 7.181050006926168e-06, 'epoch': 4.88}
# {'eval_loss': 6.538259506225586, 'eval_runtime': 11.8906, 'eval_samples_per_second': 147.512, 'eval_steps_per_second': 9.251, 'epoch': 4.88}
# {'eval_loss': 6.628991603851318, 'eval_runtime': 11.9223, 'eval_samples_per_second': 147.119, 'eval_steps_per_second': 9.226, 'epoch': 4.98}
# {'eval_loss': 6.377981662750244, 'eval_runtime': 11.8554, 'eval_samples_per_second': 147.95, 'eval_steps_per_second': 9.278, 'epoch': 5.08}
# {'train_runtime': 1566.2464, 'train_samples_per_second': 78.398, 'train_steps_per_second': 9.807, 'train_loss': 20.703318751408503, 'epoch': 5.08}
# {'eval_loss': 5.703686714172363, 'eval_runtime': 11.761, 'eval_samples_per_second': 149.137, 'eval_steps_per_second': 9.353, 'epoch': 5.08}
# got a better model, with score 5.7037 saving...
# saved
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 1e-05, 'repeats': 0, 'weight_decay': 0.01}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 6.346975803375244, 'eval_runtime': 11.8375, 'eval_samples_per_second': 148.174, 'eval_steps_per_second': 9.293, 'epoch': 0.1}
# {'eval_loss': 6.369116306304932, 'eval_runtime': 11.8649, 'eval_samples_per_second': 147.831, 'eval_steps_per_second': 9.271, 'epoch': 0.2}
# {'eval_loss': 5.926369667053223, 'eval_runtime': 11.8923, 'eval_samples_per_second': 147.491, 'eval_steps_per_second': 9.25, 'epoch': 0.29}
# {'eval_loss': 6.436915397644043, 'eval_runtime': 11.8534, 'eval_samples_per_second': 147.974, 'eval_steps_per_second': 9.28, 'epoch': 0.39}
# {'loss': 3.8754, 'learning_rate': 5.368763557483731e-06, 'epoch': 0.49}
# {'eval_loss': 7.223015785217285, 'eval_runtime': 11.8588, 'eval_samples_per_second': 147.907, 'eval_steps_per_second': 9.276, 'epoch': 0.49}
# {'eval_loss': 6.196063041687012, 'eval_runtime': 11.873, 'eval_samples_per_second': 147.73, 'eval_steps_per_second': 9.265, 'epoch': 0.59}
# {'eval_loss': 6.690802574157715, 'eval_runtime': 11.8851, 'eval_samples_per_second': 147.579, 'eval_steps_per_second': 9.255, 'epoch': 0.68}
# {'eval_loss': 6.411359786987305, 'eval_runtime': 11.8856, 'eval_samples_per_second': 147.574, 'eval_steps_per_second': 9.255, 'epoch': 0.78}
# {'eval_loss': 6.165003299713135, 'eval_runtime': 11.9192, 'eval_samples_per_second': 147.157, 'eval_steps_per_second': 9.229, 'epoch': 0.88}
# {'loss': 4.0398, 'learning_rate': 9.950131597174125e-06, 'epoch': 0.98}
# {'eval_loss': 6.161192893981934, 'eval_runtime': 11.8312, 'eval_samples_per_second': 148.252, 'eval_steps_per_second': 9.297, 'epoch': 0.98}
# {'eval_loss': 6.771516799926758, 'eval_runtime': 11.8874, 'eval_samples_per_second': 147.551, 'eval_steps_per_second': 9.254, 'epoch': 1.07}
# {'eval_loss': 5.745428085327148, 'eval_runtime': 11.9028, 'eval_samples_per_second': 147.361, 'eval_steps_per_second': 9.242, 'epoch': 1.17}
# {'eval_loss': 6.573172569274902, 'eval_runtime': 11.7595, 'eval_samples_per_second': 149.156, 'eval_steps_per_second': 9.354, 'epoch': 1.27}
# {'eval_loss': 7.312304496765137, 'eval_runtime': 11.7341, 'eval_samples_per_second': 149.478, 'eval_steps_per_second': 9.374, 'epoch': 1.37}
# {'loss': 3.3874, 'learning_rate': 9.603823244216652e-06, 'epoch': 1.46}
# {'eval_loss': 6.804939270019531, 'eval_runtime': 11.8154, 'eval_samples_per_second': 148.451, 'eval_steps_per_second': 9.31, 'epoch': 1.46}
# {'eval_loss': 7.962038993835449, 'eval_runtime': 11.8855, 'eval_samples_per_second': 147.575, 'eval_steps_per_second': 9.255, 'epoch': 1.56}
# {'eval_loss': 5.914265155792236, 'eval_runtime': 11.9063, 'eval_samples_per_second': 147.317, 'eval_steps_per_second': 9.239, 'epoch': 1.66}
# {'eval_loss': 5.756563663482666, 'eval_runtime': 11.8104, 'eval_samples_per_second': 148.513, 'eval_steps_per_second': 9.314, 'epoch': 1.76}
# {'eval_loss': 6.420856475830078, 'eval_runtime': 11.8314, 'eval_samples_per_second': 148.249, 'eval_steps_per_second': 9.297, 'epoch': 1.86}
# {'loss': 3.1386, 'learning_rate': 9.25751489125918e-06, 'epoch': 1.95}
# {'eval_loss': 6.484756946563721, 'eval_runtime': 11.8781, 'eval_samples_per_second': 147.667, 'eval_steps_per_second': 9.261, 'epoch': 1.95}
# {'eval_loss': 5.887676239013672, 'eval_runtime': 11.9031, 'eval_samples_per_second': 147.356, 'eval_steps_per_second': 9.241, 'epoch': 2.05}
# {'eval_loss': 6.334317207336426, 'eval_runtime': 11.8016, 'eval_samples_per_second': 148.624, 'eval_steps_per_second': 9.321, 'epoch': 2.15}
# {'eval_loss': 7.11151647567749, 'eval_runtime': 11.8131, 'eval_samples_per_second': 148.48, 'eval_steps_per_second': 9.312, 'epoch': 2.25}
# {'eval_loss': 5.887337684631348, 'eval_runtime': 11.8341, 'eval_samples_per_second': 148.216, 'eval_steps_per_second': 9.295, 'epoch': 2.34}
# {'loss': 2.7006, 'learning_rate': 8.911206538301705e-06, 'epoch': 2.44}
# {'eval_loss': 6.474926948547363, 'eval_runtime': 11.9074, 'eval_samples_per_second': 147.303, 'eval_steps_per_second': 9.238, 'epoch': 2.44}
# {'eval_loss': 6.778598785400391, 'eval_runtime': 11.8962, 'eval_samples_per_second': 147.442, 'eval_steps_per_second': 9.247, 'epoch': 2.54}
# {'eval_loss': 7.0395636558532715, 'eval_runtime': 11.8791, 'eval_samples_per_second': 147.654, 'eval_steps_per_second': 9.26, 'epoch': 2.64}
# {'eval_loss': 6.3450026512146, 'eval_runtime': 11.8934, 'eval_samples_per_second': 147.477, 'eval_steps_per_second': 9.249, 'epoch': 2.73}
# {'eval_loss': 8.065313339233398, 'eval_runtime': 11.8401, 'eval_samples_per_second': 148.14, 'eval_steps_per_second': 9.29, 'epoch': 2.83}
# {'loss': 2.9613, 'learning_rate': 8.564898185344232e-06, 'epoch': 2.93}
# {'eval_loss': 7.354071140289307, 'eval_runtime': 11.8753, 'eval_samples_per_second': 147.701, 'eval_steps_per_second': 9.263, 'epoch': 2.93}
# {'eval_loss': 6.413670539855957, 'eval_runtime': 11.8902, 'eval_samples_per_second': 147.517, 'eval_steps_per_second': 9.251, 'epoch': 3.03}
# {'eval_loss': 6.970818042755127, 'eval_runtime': 11.8904, 'eval_samples_per_second': 147.514, 'eval_steps_per_second': 9.251, 'epoch': 3.12}
# {'eval_loss': 8.074359893798828, 'eval_runtime': 11.8914, 'eval_samples_per_second': 147.502, 'eval_steps_per_second': 9.25, 'epoch': 3.22}
# {'eval_loss': 6.7973127365112305, 'eval_runtime': 11.8924, 'eval_samples_per_second': 147.489, 'eval_steps_per_second': 9.25, 'epoch': 3.32}
# {'loss': 2.3694, 'learning_rate': 8.218589832386758e-06, 'epoch': 3.42}
# {'eval_loss': 8.294671058654785, 'eval_runtime': 11.8991, 'eval_samples_per_second': 147.406, 'eval_steps_per_second': 9.244, 'epoch': 3.42}
# {'eval_loss': 6.580931663513184, 'eval_runtime': 11.9065, 'eval_samples_per_second': 147.314, 'eval_steps_per_second': 9.239, 'epoch': 3.52}
# {'eval_loss': 6.634856700897217, 'eval_runtime': 11.8679, 'eval_samples_per_second': 147.793, 'eval_steps_per_second': 9.269, 'epoch': 3.61}
# {'eval_loss': 7.248664855957031, 'eval_runtime': 11.9016, 'eval_samples_per_second': 147.375, 'eval_steps_per_second': 9.242, 'epoch': 3.71}
# {'eval_loss': 6.37716007232666, 'eval_runtime': 11.9201, 'eval_samples_per_second': 147.146, 'eval_steps_per_second': 9.228, 'epoch': 3.81}
# {'loss': 2.2406, 'learning_rate': 7.872281479429285e-06, 'epoch': 3.91}
# {'eval_loss': 7.671542167663574, 'eval_runtime': 11.8225, 'eval_samples_per_second': 148.362, 'eval_steps_per_second': 9.304, 'epoch': 3.91}
# {'eval_loss': 6.075002670288086, 'eval_runtime': 11.8551, 'eval_samples_per_second': 147.953, 'eval_steps_per_second': 9.279, 'epoch': 0.39}
# {'loss': 3.3916, 'learning_rate': 1.0715835140997832e-05, 'epoch': 0.49}
# {'eval_loss': 7.279268264770508, 'eval_runtime': 11.833, 'eval_samples_per_second': 148.23, 'eval_steps_per_second': 9.296, 'epoch': 0.49}
# {'eval_loss': 7.492400646209717, 'eval_runtime': 11.8388, 'eval_samples_per_second': 148.157, 'eval_steps_per_second': 9.291, 'epoch': 0.59}
# {'eval_loss': 6.650681018829346, 'eval_runtime': 11.8664, 'eval_samples_per_second': 147.812, 'eval_steps_per_second': 9.27, 'epoch': 0.68}
# {'eval_loss': 6.307239532470703, 'eval_runtime': 11.9042, 'eval_samples_per_second': 147.344, 'eval_steps_per_second': 9.24, 'epoch': 0.78}
# {'eval_loss': 5.903184413909912, 'eval_runtime': 11.887, 'eval_samples_per_second': 147.556, 'eval_steps_per_second': 9.254, 'epoch': 0.88}
# {'loss': 3.0222, 'learning_rate': 1.990026319434825e-05, 'epoch': 0.98}
# {'eval_loss': 7.74117374420166, 'eval_runtime': 11.838, 'eval_samples_per_second': 148.167, 'eval_steps_per_second': 9.292, 'epoch': 0.98}
# {'eval_loss': 7.523496627807617, 'eval_runtime': 11.7988, 'eval_samples_per_second': 148.659, 'eval_steps_per_second': 9.323, 'epoch': 1.07}
# {'eval_loss': 6.92556095123291, 'eval_runtime': 11.8453, 'eval_samples_per_second': 148.075, 'eval_steps_per_second': 9.286, 'epoch': 1.17}
# {'eval_loss': 6.911492347717285, 'eval_runtime': 11.8865, 'eval_samples_per_second': 147.562, 'eval_steps_per_second': 9.254, 'epoch': 1.27}
# {'eval_loss': 6.535569190979004, 'eval_runtime': 11.8397, 'eval_samples_per_second': 148.145, 'eval_steps_per_second': 9.291, 'epoch': 1.37}
# {'loss': 2.5442, 'learning_rate': 1.9207646488433304e-05, 'epoch': 1.46}
# {'eval_loss': 6.823901176452637, 'eval_runtime': 11.8516, 'eval_samples_per_second': 147.997, 'eval_steps_per_second': 9.281, 'epoch': 1.46}
# {'eval_loss': 7.913190841674805, 'eval_runtime': 11.8634, 'eval_samples_per_second': 147.849, 'eval_steps_per_second': 9.272, 'epoch': 1.56}
# {'eval_loss': 6.455235481262207, 'eval_runtime': 11.8823, 'eval_samples_per_second': 147.614, 'eval_steps_per_second': 9.257, 'epoch': 1.66}
# {'eval_loss': 5.916287422180176, 'eval_runtime': 11.9051, 'eval_samples_per_second': 147.332, 'eval_steps_per_second': 9.24, 'epoch': 1.76}
# {'eval_loss': 7.61232852935791, 'eval_runtime': 11.8689, 'eval_samples_per_second': 147.781, 'eval_steps_per_second': 9.268, 'epoch': 1.86}
# {'loss': 2.9231, 'learning_rate': 1.851502978251836e-05, 'epoch': 1.95}
# {'eval_loss': 7.265335559844971, 'eval_runtime': 11.8875, 'eval_samples_per_second': 147.55, 'eval_steps_per_second': 9.253, 'epoch': 1.95}
# {'eval_loss': 6.492586135864258, 'eval_runtime': 11.8984, 'eval_samples_per_second': 147.415, 'eval_steps_per_second': 9.245, 'epoch': 2.05}
# {'eval_loss': 6.14121675491333, 'eval_runtime': 11.8907, 'eval_samples_per_second': 147.511, 'eval_steps_per_second': 9.251, 'epoch': 2.15}
# {'eval_loss': 6.929041862487793, 'eval_runtime': 11.8678, 'eval_samples_per_second': 147.795, 'eval_steps_per_second': 9.269, 'epoch': 2.25}
# {'eval_loss': 6.988967418670654, 'eval_runtime': 11.8954, 'eval_samples_per_second': 147.452, 'eval_steps_per_second': 9.247, 'epoch': 2.34}
# {'loss': 2.1561, 'learning_rate': 1.782241307660341e-05, 'epoch': 2.44}
# {'eval_loss': 6.279405117034912, 'eval_runtime': 11.8881, 'eval_samples_per_second': 147.542, 'eval_steps_per_second': 9.253, 'epoch': 2.44}
# {'eval_loss': 9.192858695983887, 'eval_runtime': 11.8877, 'eval_samples_per_second': 147.547, 'eval_steps_per_second': 9.253, 'epoch': 2.54}
# {'eval_loss': 6.902989387512207, 'eval_runtime': 11.9226, 'eval_samples_per_second': 147.115, 'eval_steps_per_second': 9.226, 'epoch': 2.64}
# {'eval_loss': 6.4386067390441895, 'eval_runtime': 11.8699, 'eval_samples_per_second': 147.769, 'eval_steps_per_second': 9.267, 'epoch': 2.73}
# {'eval_loss': 8.038958549499512, 'eval_runtime': 11.8829, 'eval_samples_per_second': 147.608, 'eval_steps_per_second': 9.257, 'epoch': 2.83}
# {'loss': 2.3261, 'learning_rate': 1.7129796370688464e-05, 'epoch': 2.93}
# {'eval_loss': 6.489595413208008, 'eval_runtime': 11.9158, 'eval_samples_per_second': 147.2, 'eval_steps_per_second': 9.231, 'epoch': 2.93}
# {'eval_loss': 7.161843299865723, 'eval_runtime': 11.9128, 'eval_samples_per_second': 147.237, 'eval_steps_per_second': 9.234, 'epoch': 3.03}
# {'eval_loss': 6.208231449127197, 'eval_runtime': 11.8663, 'eval_samples_per_second': 147.814, 'eval_steps_per_second': 9.27, 'epoch': 3.12}
# {'eval_loss': 6.778312683105469, 'eval_runtime': 11.8721, 'eval_samples_per_second': 147.742, 'eval_steps_per_second': 9.265, 'epoch': 3.22}
# {'train_runtime': 999.1213, 'train_samples_per_second': 122.898, 'train_steps_per_second': 15.374, 'train_loss': 2.6351887281013258, 'epoch': 3.22}
# {'eval_loss': 5.697977066040039, 'eval_runtime': 11.7952, 'eval_samples_per_second': 148.705, 'eval_steps_per_second': 9.326, 'epoch': 3.22}
# got a better model, with score 5.698 saving...
# saved
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 2e-05, 'repeats': 0, 'weight_decay': 0.01}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 7.104362487792969, 'eval_runtime': 11.896, 'eval_samples_per_second': 147.444, 'eval_steps_per_second': 9.247, 'epoch': 0.1}
# {'eval_loss': 6.403736114501953, 'eval_runtime': 11.9038, 'eval_samples_per_second': 147.348, 'eval_steps_per_second': 9.241, 'epoch': 0.2}
# {'eval_loss': 5.966161251068115, 'eval_runtime': 11.8883, 'eval_samples_per_second': 147.54, 'eval_steps_per_second': 9.253, 'epoch': 0.29}
# {'eval_loss': 6.149171829223633, 'eval_runtime': 11.8992, 'eval_samples_per_second': 147.405, 'eval_steps_per_second': 9.244, 'epoch': 0.39}
# {'loss': 3.118, 'learning_rate': 1.0715835140997832e-05, 'epoch': 0.49}
# {'eval_loss': 7.2716875076293945, 'eval_runtime': 11.8785, 'eval_samples_per_second': 147.662, 'eval_steps_per_second': 9.26, 'epoch': 0.49}
# {'eval_loss': 7.563057899475098, 'eval_runtime': 11.8535, 'eval_samples_per_second': 147.973, 'eval_steps_per_second': 9.28, 'epoch': 0.59}
# {'eval_loss': 6.707124710083008, 'eval_runtime': 11.8865, 'eval_samples_per_second': 147.562, 'eval_steps_per_second': 9.254, 'epoch': 0.68}
# {'eval_loss': 6.097998142242432, 'eval_runtime': 11.9116, 'eval_samples_per_second': 147.251, 'eval_steps_per_second': 9.235, 'epoch': 0.78}
# {'eval_loss': 5.898799419403076, 'eval_runtime': 11.9295, 'eval_samples_per_second': 147.03, 'eval_steps_per_second': 9.221, 'epoch': 0.88}
# {'loss': 3.0219, 'learning_rate': 1.990026319434825e-05, 'epoch': 0.98}
# {'eval_loss': 7.727797508239746, 'eval_runtime': 11.8606, 'eval_samples_per_second': 147.885, 'eval_steps_per_second': 9.274, 'epoch': 0.98}
# {'eval_loss': 6.862722396850586, 'eval_runtime': 11.8761, 'eval_samples_per_second': 147.691, 'eval_steps_per_second': 9.262, 'epoch': 1.07}
# {'eval_loss': 7.1858086585998535, 'eval_runtime': 11.9051, 'eval_samples_per_second': 147.332, 'eval_steps_per_second': 9.24, 'epoch': 1.17}
# {'eval_loss': 6.879586696624756, 'eval_runtime': 11.8605, 'eval_samples_per_second': 147.886, 'eval_steps_per_second': 9.274, 'epoch': 1.27}
# {'eval_loss': 6.4504804611206055, 'eval_runtime': 11.8241, 'eval_samples_per_second': 148.341, 'eval_steps_per_second': 9.303, 'epoch': 1.37}
# {'loss': 2.4846, 'learning_rate': 1.9207646488433304e-05, 'epoch': 1.46}
# {'eval_loss': 6.670257091522217, 'eval_runtime': 11.8712, 'eval_samples_per_second': 147.752, 'eval_steps_per_second': 9.266, 'epoch': 1.46}
# {'eval_loss': 8.250001907348633, 'eval_runtime': 11.8975, 'eval_samples_per_second': 147.426, 'eval_steps_per_second': 9.246, 'epoch': 1.56}
# {'eval_loss': 6.517288684844971, 'eval_runtime': 11.9244, 'eval_samples_per_second': 147.093, 'eval_steps_per_second': 9.225, 'epoch': 1.66}
# {'eval_loss': 5.869314193725586, 'eval_runtime': 11.7771, 'eval_samples_per_second': 148.933, 'eval_steps_per_second': 9.34, 'epoch': 1.76}
# {'eval_loss': 7.326204299926758, 'eval_runtime': 11.837, 'eval_samples_per_second': 148.179, 'eval_steps_per_second': 9.293, 'epoch': 1.86}
# {'loss': 2.8692, 'learning_rate': 1.851502978251836e-05, 'epoch': 1.95}
# {'eval_loss': 7.395010948181152, 'eval_runtime': 11.8951, 'eval_samples_per_second': 147.456, 'eval_steps_per_second': 9.248, 'epoch': 1.95}
# {'eval_loss': 6.740108966827393, 'eval_runtime': 11.8587, 'eval_samples_per_second': 147.908, 'eval_steps_per_second': 9.276, 'epoch': 2.05}
# {'eval_loss': 6.039005756378174, 'eval_runtime': 11.7948, 'eval_samples_per_second': 148.71, 'eval_steps_per_second': 9.326, 'epoch': 2.15}
# {'eval_loss': 6.489835739135742, 'eval_runtime': 11.8606, 'eval_samples_per_second': 147.885, 'eval_steps_per_second': 9.274, 'epoch': 2.25}
# {'eval_loss': 6.910979270935059, 'eval_runtime': 11.9407, 'eval_samples_per_second': 146.893, 'eval_steps_per_second': 9.212, 'epoch': 2.34}
# {'loss': 2.1135, 'learning_rate': 1.782241307660341e-05, 'epoch': 2.44}
# {'eval_loss': 6.160913467407227, 'eval_runtime': 11.8736, 'eval_samples_per_second': 147.723, 'eval_steps_per_second': 9.264, 'epoch': 2.44}
# {'eval_loss': 9.039156913757324, 'eval_runtime': 11.8435, 'eval_samples_per_second': 148.098, 'eval_steps_per_second': 9.288, 'epoch': 2.54}
# {'eval_loss': 6.897448539733887, 'eval_runtime': 11.8649, 'eval_samples_per_second': 147.831, 'eval_steps_per_second': 9.271, 'epoch': 2.64}
# {'eval_loss': 6.62351655960083, 'eval_runtime': 11.8965, 'eval_samples_per_second': 147.438, 'eval_steps_per_second': 9.246, 'epoch': 2.73}
# {'eval_loss': 7.934786319732666, 'eval_runtime': 11.9214, 'eval_samples_per_second': 147.13, 'eval_steps_per_second': 9.227, 'epoch': 2.83}
# {'loss': 2.245, 'learning_rate': 1.7129796370688464e-05, 'epoch': 2.93}
# {'eval_loss': 6.327080726623535, 'eval_runtime': 11.8321, 'eval_samples_per_second': 148.241, 'eval_steps_per_second': 9.297, 'epoch': 2.93}
# {'eval_loss': 7.091619968414307, 'eval_runtime': 11.8804, 'eval_samples_per_second': 147.638, 'eval_steps_per_second': 9.259, 'epoch': 3.03}
# {'eval_loss': 6.077588081359863, 'eval_runtime': 11.9125, 'eval_samples_per_second': 147.24, 'eval_steps_per_second': 9.234, 'epoch': 3.12}
# {'eval_loss': 7.470381259918213, 'eval_runtime': 11.8867, 'eval_samples_per_second': 147.56, 'eval_steps_per_second': 9.254, 'epoch': 3.22}
# {'eval_loss': 6.524240493774414, 'eval_runtime': 11.8845, 'eval_samples_per_second': 147.587, 'eval_steps_per_second': 9.256, 'epoch': 3.32}
# {'loss': 1.6588, 'learning_rate': 1.6437179664773515e-05, 'epoch': 3.42}
# {'eval_loss': 7.900806427001953, 'eval_runtime': 11.8927, 'eval_samples_per_second': 147.486, 'eval_steps_per_second': 9.249, 'epoch': 3.42}
# {'eval_loss': 7.451700687408447, 'eval_runtime': 11.9207, 'eval_samples_per_second': 147.139, 'eval_steps_per_second': 9.228, 'epoch': 3.52}
# {'eval_loss': 7.332395553588867, 'eval_runtime': 11.8705, 'eval_samples_per_second': 147.761, 'eval_steps_per_second': 9.267, 'epoch': 3.61}
# {'eval_loss': 7.586090564727783, 'eval_runtime': 11.8688, 'eval_samples_per_second': 147.782, 'eval_steps_per_second': 9.268, 'epoch': 3.71}
# {'eval_loss': 6.542581081390381, 'eval_runtime': 11.9048, 'eval_samples_per_second': 147.336, 'eval_steps_per_second': 9.24, 'epoch': 3.81}
# {'loss': 1.5533, 'learning_rate': 1.574456295885857e-05, 'epoch': 3.91}
# {'eval_loss': 8.369000434875488, 'eval_runtime': 11.8974, 'eval_samples_per_second': 147.428, 'eval_steps_per_second': 9.246, 'epoch': 3.91}
# {'eval_loss': 9.732263565063477, 'eval_runtime': 11.867, 'eval_samples_per_second': 147.804, 'eval_steps_per_second': 9.269, 'epoch': 4.0}
# {'eval_loss': 6.094115257263184, 'eval_runtime': 11.8815, 'eval_samples_per_second': 147.625, 'eval_steps_per_second': 9.258, 'epoch': 4.1}
# {'eval_loss': 6.557626724243164, 'eval_runtime': 11.9276, 'eval_samples_per_second': 147.054, 'eval_steps_per_second': 9.222, 'epoch': 4.2}
# {'eval_loss': 6.691938877105713, 'eval_runtime': 11.9349, 'eval_samples_per_second': 146.964, 'eval_steps_per_second': 9.217, 'epoch': 4.3}
# {'loss': 1.2668, 'learning_rate': 1.5051946252943623e-05, 'epoch': 4.39}
# {'eval_loss': 7.7530412673950195, 'eval_runtime': 11.9206, 'eval_samples_per_second': 147.14, 'eval_steps_per_second': 9.228, 'epoch': 4.39}
# {'eval_loss': 6.155955791473389, 'eval_runtime': 11.9261, 'eval_samples_per_second': 147.073, 'eval_steps_per_second': 9.223, 'epoch': 4.49}
# {'eval_loss': 7.290870666503906, 'eval_runtime': 11.9199, 'eval_samples_per_second': 147.149, 'eval_steps_per_second': 9.228, 'epoch': 4.59}
# {'eval_loss': 6.506886005401611, 'eval_runtime': 11.9209, 'eval_samples_per_second': 147.136, 'eval_steps_per_second': 9.227, 'epoch': 4.69}
# {'train_runtime': 1452.0016, 'train_samples_per_second': 84.566, 'train_steps_per_second': 10.579, 'train_loss': 2.1913162803649904, 'epoch': 4.69}
# {'eval_loss': 5.869314193725586, 'eval_runtime': 11.7855, 'eval_samples_per_second': 148.826, 'eval_steps_per_second': 9.333, 'epoch': 4.69}
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 3e-05, 'repeats': 0, 'weight_decay': 0.1}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 7.797677516937256, 'eval_runtime': 11.8519, 'eval_samples_per_second': 147.993, 'eval_steps_per_second': 9.281, 'epoch': 0.1}
# {'eval_loss': 7.765120506286621, 'eval_runtime': 11.8513, 'eval_samples_per_second': 148.001, 'eval_steps_per_second': 9.282, 'epoch': 0.2}
# {'eval_loss': 6.633825778961182, 'eval_runtime': 11.9137, 'eval_samples_per_second': 147.226, 'eval_steps_per_second': 9.233, 'epoch': 0.29}
# {'eval_loss': 7.267452239990234, 'eval_runtime': 11.8421, 'eval_samples_per_second': 148.116, 'eval_steps_per_second': 9.289, 'epoch': 0.39}
# {'loss': 2.0516, 'learning_rate': 1.6073752711496746e-05, 'epoch': 0.49}
# {'eval_loss': 8.61204719543457, 'eval_runtime': 11.8424, 'eval_samples_per_second': 148.111, 'eval_steps_per_second': 9.289, 'epoch': 0.49}
# {'eval_loss': 8.534204483032227, 'eval_runtime': 11.8768, 'eval_samples_per_second': 147.683, 'eval_steps_per_second': 9.262, 'epoch': 0.59}
# {'eval_loss': 7.270828723907471, 'eval_runtime': 11.905, 'eval_samples_per_second': 147.333, 'eval_steps_per_second': 9.24, 'epoch': 0.68}
# {'eval_loss': 5.820060729980469, 'eval_runtime': 11.9416, 'eval_samples_per_second': 146.882, 'eval_steps_per_second': 9.212, 'epoch': 0.78}
# {'eval_loss': 6.698146820068359, 'eval_runtime': 11.8, 'eval_samples_per_second': 148.644, 'eval_steps_per_second': 9.322, 'epoch': 0.88}
# {'loss': 1.5223, 'learning_rate': 2.985039479152237e-05, 'epoch': 0.98}
# {'eval_loss': 8.89726734161377, 'eval_runtime': 11.8385, 'eval_samples_per_second': 148.16, 'eval_steps_per_second': 9.292, 'epoch': 0.98}
# {'eval_loss': 12.096003532409668, 'eval_runtime': 11.8761, 'eval_samples_per_second': 147.691, 'eval_steps_per_second': 9.262, 'epoch': 1.07}
# {'eval_loss': 7.690656661987305, 'eval_runtime': 11.9341, 'eval_samples_per_second': 146.973, 'eval_steps_per_second': 9.217, 'epoch': 1.17}
# {'eval_loss': 8.602540016174316, 'eval_runtime': 11.8749, 'eval_samples_per_second': 147.706, 'eval_steps_per_second': 9.263, 'epoch': 1.27}
# {'eval_loss': 6.370920658111572, 'eval_runtime': 11.8886, 'eval_samples_per_second': 147.536, 'eval_steps_per_second': 9.253, 'epoch': 1.37}
# {'loss': 1.5303, 'learning_rate': 2.8811469732649952e-05, 'epoch': 1.46}
# {'eval_loss': 8.322057723999023, 'eval_runtime': 11.8785, 'eval_samples_per_second': 147.661, 'eval_steps_per_second': 9.26, 'epoch': 1.46}
# {'eval_loss': 8.785950660705566, 'eval_runtime': 11.9083, 'eval_samples_per_second': 147.292, 'eval_steps_per_second': 9.237, 'epoch': 1.56}
# {'eval_loss': 8.116850852966309, 'eval_runtime': 11.93, 'eval_samples_per_second': 147.024, 'eval_steps_per_second': 9.22, 'epoch': 1.66}
# {'eval_loss': 7.68171501159668, 'eval_runtime': 11.8593, 'eval_samples_per_second': 147.9, 'eval_steps_per_second': 9.275, 'epoch': 1.76}
# {'eval_loss': 8.043595314025879, 'eval_runtime': 11.8499, 'eval_samples_per_second': 148.019, 'eval_steps_per_second': 9.283, 'epoch': 1.86}
# {'loss': 1.883, 'learning_rate': 2.7772544673777534e-05, 'epoch': 1.95}
# {'eval_loss': 7.193422794342041, 'eval_runtime': 11.8109, 'eval_samples_per_second': 148.507, 'eval_steps_per_second': 9.313, 'epoch': 1.95}
# {'eval_loss': 7.616630554199219, 'eval_runtime': 11.8806, 'eval_samples_per_second': 147.635, 'eval_steps_per_second': 9.259, 'epoch': 2.05}
# {'eval_loss': 6.669011116027832, 'eval_runtime': 11.9143, 'eval_samples_per_second': 147.218, 'eval_steps_per_second': 9.233, 'epoch': 2.15}
# {'eval_loss': 5.567257881164551, 'eval_runtime': 11.8999, 'eval_samples_per_second': 147.396, 'eval_steps_per_second': 9.244, 'epoch': 2.25}
# {'eval_loss': 6.907135486602783, 'eval_runtime': 11.9182, 'eval_samples_per_second': 147.169, 'eval_steps_per_second': 9.23, 'epoch': 2.34}
# {'loss': 1.8801, 'learning_rate': 2.6733619614905113e-05, 'epoch': 2.44}
# {'eval_loss': 5.918585300445557, 'eval_runtime': 11.9283, 'eval_samples_per_second': 147.045, 'eval_steps_per_second': 9.222, 'epoch': 2.44}
# {'eval_loss': 7.603179454803467, 'eval_runtime': 11.9366, 'eval_samples_per_second': 146.944, 'eval_steps_per_second': 9.215, 'epoch': 2.54}
# {'eval_loss': 7.765614032745361, 'eval_runtime': 11.8841, 'eval_samples_per_second': 147.593, 'eval_steps_per_second': 9.256, 'epoch': 2.64}
# {'eval_loss': 6.444816589355469, 'eval_runtime': 11.9116, 'eval_samples_per_second': 147.252, 'eval_steps_per_second': 9.235, 'epoch': 2.73}
# {'eval_loss': 7.336737155914307, 'eval_runtime': 11.9111, 'eval_samples_per_second': 147.258, 'eval_steps_per_second': 9.235, 'epoch': 2.83}
# {'loss': 1.8491, 'learning_rate': 2.5694694556032695e-05, 'epoch': 2.93}
# {'eval_loss': 7.97330379486084, 'eval_runtime': 11.9467, 'eval_samples_per_second': 146.819, 'eval_steps_per_second': 9.208, 'epoch': 2.93}
# {'eval_loss': 7.951010227203369, 'eval_runtime': 11.8813, 'eval_samples_per_second': 147.627, 'eval_steps_per_second': 9.258, 'epoch': 3.03}
# {'eval_loss': 6.4119367599487305, 'eval_runtime': 11.864, 'eval_samples_per_second': 147.842, 'eval_steps_per_second': 9.272, 'epoch': 3.12}
# {'eval_loss': 7.172668933868408, 'eval_runtime': 11.8778, 'eval_samples_per_second': 147.67, 'eval_steps_per_second': 9.261, 'epoch': 3.22}
# {'eval_loss': 6.374386787414551, 'eval_runtime': 11.9019, 'eval_samples_per_second': 147.372, 'eval_steps_per_second': 9.242, 'epoch': 3.32}
# {'loss': 1.3407, 'learning_rate': 2.465576949716027e-05, 'epoch': 3.42}
# {'eval_loss': 8.487064361572266, 'eval_runtime': 11.9249, 'eval_samples_per_second': 147.087, 'eval_steps_per_second': 9.224, 'epoch': 3.42}
# {'eval_loss': 6.468832492828369, 'eval_runtime': 11.8717, 'eval_samples_per_second': 147.746, 'eval_steps_per_second': 9.266, 'epoch': 3.52}
# {'eval_loss': 6.88357400894165, 'eval_runtime': 11.8813, 'eval_samples_per_second': 147.627, 'eval_steps_per_second': 9.258, 'epoch': 3.61}
# {'eval_loss': 6.632162094116211, 'eval_runtime': 11.8983, 'eval_samples_per_second': 147.416, 'eval_steps_per_second': 9.245, 'epoch': 3.71}
# {'eval_loss': 6.6490631103515625, 'eval_runtime': 11.8845, 'eval_samples_per_second': 147.587, 'eval_steps_per_second': 9.256, 'epoch': 3.81}
# {'loss': 1.311, 'learning_rate': 2.361684443828785e-05, 'epoch': 3.91}
# {'eval_loss': 8.508459091186523, 'eval_runtime': 11.9026, 'eval_samples_per_second': 147.363, 'eval_steps_per_second': 9.242, 'epoch': 3.91}
# {'eval_loss': 8.684062957763672, 'eval_runtime': 11.9081, 'eval_samples_per_second': 147.294, 'eval_steps_per_second': 9.237, 'epoch': 4.0}
# {'eval_loss': 6.1786651611328125, 'eval_runtime': 11.8747, 'eval_samples_per_second': 147.71, 'eval_steps_per_second': 9.263, 'epoch': 4.1}
# {'eval_loss': 5.983610153198242, 'eval_runtime': 11.8854, 'eval_samples_per_second': 147.577, 'eval_steps_per_second': 9.255, 'epoch': 4.2}
# {'eval_loss': 7.317412376403809, 'eval_runtime': 11.8977, 'eval_samples_per_second': 147.423, 'eval_steps_per_second': 9.245, 'epoch': 4.3}
# {'loss': 1.0515, 'learning_rate': 2.2577919379415434e-05, 'epoch': 4.39}
# {'eval_loss': 7.314606666564941, 'eval_runtime': 11.8971, 'eval_samples_per_second': 147.431, 'eval_steps_per_second': 9.246, 'epoch': 4.39}
# {'eval_loss': 5.920641899108887, 'eval_runtime': 11.9105, 'eval_samples_per_second': 147.265, 'eval_steps_per_second': 9.236, 'epoch': 4.49}
# {'eval_loss': 8.273134231567383, 'eval_runtime': 11.9366, 'eval_samples_per_second': 146.943, 'eval_steps_per_second': 9.215, 'epoch': 4.59}
# {'eval_loss': 6.713674545288086, 'eval_runtime': 11.9252, 'eval_samples_per_second': 147.083, 'eval_steps_per_second': 9.224, 'epoch': 4.69}
# {'eval_loss': 7.108985424041748, 'eval_runtime': 11.8905, 'eval_samples_per_second': 147.512, 'eval_steps_per_second': 9.251, 'epoch': 4.79}
# {'loss': 0.9989, 'learning_rate': 2.1538994320543012e-05, 'epoch': 4.88}
# {'eval_loss': 6.417685031890869, 'eval_runtime': 11.8853, 'eval_samples_per_second': 147.578, 'eval_steps_per_second': 9.255, 'epoch': 4.88}
# {'eval_loss': 5.998353481292725, 'eval_runtime': 11.9232, 'eval_samples_per_second': 147.108, 'eval_steps_per_second': 9.226, 'epoch': 4.98}
# {'eval_loss': 6.996560096740723, 'eval_runtime': 11.9285, 'eval_samples_per_second': 147.042, 'eval_steps_per_second': 9.222, 'epoch': 5.08}
# {'eval_loss': 8.41776180267334, 'eval_runtime': 11.8685, 'eval_samples_per_second': 147.786, 'eval_steps_per_second': 9.268, 'epoch': 5.18}
# {'train_runtime': 1605.6191, 'train_samples_per_second': 76.475, 'train_steps_per_second': 9.566, 'train_loss': 1.5026524468188016, 'epoch': 5.18}
# {'eval_loss': 5.567257881164551, 'eval_runtime': 11.8026, 'eval_samples_per_second': 148.612, 'eval_steps_per_second': 9.32, 'epoch': 5.18}
# got a better model, with score 5.5673 saving...
# saved
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 3e-05, 'repeats': 0, 'weight_decay': 0.01}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 6.9748077392578125, 'eval_runtime': 11.8872, 'eval_samples_per_second': 147.553, 'eval_steps_per_second': 9.254, 'epoch': 0.1}
# {'eval_loss': 6.785513877868652, 'eval_runtime': 11.9008, 'eval_samples_per_second': 147.385, 'eval_steps_per_second': 9.243, 'epoch': 0.2}
# {'eval_loss': 6.6102423667907715, 'eval_runtime': 11.9083, 'eval_samples_per_second': 147.292, 'eval_steps_per_second': 9.237, 'epoch': 0.29}
# {'eval_loss': 7.048332214355469, 'eval_runtime': 11.9259, 'eval_samples_per_second': 147.075, 'eval_steps_per_second': 9.224, 'epoch': 0.39}
# {'loss': 1.2901, 'learning_rate': 1.613882863340564e-05, 'epoch': 0.49}
# {'eval_loss': 7.6158647537231445, 'eval_runtime': 11.9476, 'eval_samples_per_second': 146.808, 'eval_steps_per_second': 9.207, 'epoch': 0.49}
# {'eval_loss': 6.812314033508301, 'eval_runtime': 11.8774, 'eval_samples_per_second': 147.675, 'eval_steps_per_second': 9.261, 'epoch': 0.59}
# {'eval_loss': 7.391963005065918, 'eval_runtime': 11.8509, 'eval_samples_per_second': 148.006, 'eval_steps_per_second': 9.282, 'epoch': 0.68}
# {'eval_loss': 6.312751293182373, 'eval_runtime': 11.8745, 'eval_samples_per_second': 147.712, 'eval_steps_per_second': 9.264, 'epoch': 0.78}
# {'eval_loss': 6.249794960021973, 'eval_runtime': 11.9272, 'eval_samples_per_second': 147.058, 'eval_steps_per_second': 9.223, 'epoch': 0.88}
# {'loss': 1.0323, 'learning_rate': 2.984831694140463e-05, 'epoch': 0.98}
# {'eval_loss': 5.878511428833008, 'eval_runtime': 11.9058, 'eval_samples_per_second': 147.323, 'eval_steps_per_second': 9.239, 'epoch': 0.98}
# {'eval_loss': 5.814651012420654, 'eval_runtime': 11.9021, 'eval_samples_per_second': 147.369, 'eval_steps_per_second': 9.242, 'epoch': 1.07}
# {'eval_loss': 6.041768550872803, 'eval_runtime': 11.9027, 'eval_samples_per_second': 147.361, 'eval_steps_per_second': 9.242, 'epoch': 1.17}
# {'eval_loss': 6.203568935394287, 'eval_runtime': 11.8996, 'eval_samples_per_second': 147.4, 'eval_steps_per_second': 9.244, 'epoch': 1.27}
# {'eval_loss': 6.891125202178955, 'eval_runtime': 11.8294, 'eval_samples_per_second': 148.275, 'eval_steps_per_second': 9.299, 'epoch': 1.37}
# {'loss': 1.2991, 'learning_rate': 2.8809391882532208e-05, 'epoch': 1.46}
# {'eval_loss': 7.733008861541748, 'eval_runtime': 11.8599, 'eval_samples_per_second': 147.894, 'eval_steps_per_second': 9.275, 'epoch': 1.46}
# {'eval_loss': 8.849654197692871, 'eval_runtime': 11.9049, 'eval_samples_per_second': 147.334, 'eval_steps_per_second': 9.24, 'epoch': 1.56}
# {'eval_loss': 5.740498065948486, 'eval_runtime': 11.9403, 'eval_samples_per_second': 146.897, 'eval_steps_per_second': 9.212, 'epoch': 1.66}
# {'eval_loss': 6.445288181304932, 'eval_runtime': 11.9208, 'eval_samples_per_second': 147.138, 'eval_steps_per_second': 9.228, 'epoch': 1.76}
# {'eval_loss': 6.500792503356934, 'eval_runtime': 11.9344, 'eval_samples_per_second': 146.97, 'eval_steps_per_second': 9.217, 'epoch': 1.86}
# {'loss': 1.1625, 'learning_rate': 2.777046682365979e-05, 'epoch': 1.95}
# {'eval_loss': 8.391693115234375, 'eval_runtime': 11.958, 'eval_samples_per_second': 146.68, 'eval_steps_per_second': 9.199, 'epoch': 1.95}
# {'eval_loss': 7.247210502624512, 'eval_runtime': 11.889, 'eval_samples_per_second': 147.531, 'eval_steps_per_second': 9.252, 'epoch': 2.05}
# {'eval_loss': 6.620296478271484, 'eval_runtime': 11.8646, 'eval_samples_per_second': 147.835, 'eval_steps_per_second': 9.271, 'epoch': 2.15}
# {'eval_loss': 6.40748929977417, 'eval_runtime': 11.8773, 'eval_samples_per_second': 147.676, 'eval_steps_per_second': 9.261, 'epoch': 2.25}
# {'eval_loss': 6.629740238189697, 'eval_runtime': 11.8995, 'eval_samples_per_second': 147.401, 'eval_steps_per_second': 9.244, 'epoch': 2.34}
# {'loss': 1.0746, 'learning_rate': 2.6731541764787365e-05, 'epoch': 2.44}
# {'eval_loss': 6.230549335479736, 'eval_runtime': 11.9186, 'eval_samples_per_second': 147.165, 'eval_steps_per_second': 9.229, 'epoch': 2.44}
# {'eval_loss': 7.81464958190918, 'eval_runtime': 11.9116, 'eval_samples_per_second': 147.251, 'eval_steps_per_second': 9.235, 'epoch': 2.54}
# {'eval_loss': 6.989864349365234, 'eval_runtime': 11.9272, 'eval_samples_per_second': 147.058, 'eval_steps_per_second': 9.223, 'epoch': 2.64}
# {'eval_loss': 6.729933738708496, 'eval_runtime': 11.8991, 'eval_samples_per_second': 147.406, 'eval_steps_per_second': 9.244, 'epoch': 2.73}
# {'eval_loss': 7.490065097808838, 'eval_runtime': 11.8957, 'eval_samples_per_second': 147.448, 'eval_steps_per_second': 9.247, 'epoch': 2.83}
# {'loss': 1.3424, 'learning_rate': 2.5694694556032695e-05, 'epoch': 2.93}
# {'eval_loss': 6.641585826873779, 'eval_runtime': 11.9167, 'eval_samples_per_second': 147.189, 'eval_steps_per_second': 9.231, 'epoch': 2.93}
# {'eval_loss': 6.739932537078857, 'eval_runtime': 11.9204, 'eval_samples_per_second': 147.143, 'eval_steps_per_second': 9.228, 'epoch': 3.03}
# {'eval_loss': 6.267861366271973, 'eval_runtime': 11.9282, 'eval_samples_per_second': 147.046, 'eval_steps_per_second': 9.222, 'epoch': 3.12}
# {'eval_loss': 6.911664009094238, 'eval_runtime': 11.8961, 'eval_samples_per_second': 147.443, 'eval_steps_per_second': 9.247, 'epoch': 3.22}
# {'eval_loss': 6.708296775817871, 'eval_runtime': 11.8886, 'eval_samples_per_second': 147.537, 'eval_steps_per_second': 9.253, 'epoch': 3.32}
# {'loss': 1.0349, 'learning_rate': 2.465576949716027e-05, 'epoch': 3.42}
# {'eval_loss': 8.070752143859863, 'eval_runtime': 11.8205, 'eval_samples_per_second': 148.386, 'eval_steps_per_second': 9.306, 'epoch': 3.42}
# {'eval_loss': 6.474507808685303, 'eval_runtime': 11.855, 'eval_samples_per_second': 147.954, 'eval_steps_per_second': 9.279, 'epoch': 3.52}
# {'eval_loss': 7.051862716674805, 'eval_runtime': 11.9167, 'eval_samples_per_second': 147.188, 'eval_steps_per_second': 9.231, 'epoch': 3.61}
# {'eval_loss': 6.936083793640137, 'eval_runtime': 11.9263, 'eval_samples_per_second': 147.07, 'eval_steps_per_second': 9.223, 'epoch': 3.71}
# {'eval_loss': 6.068696975708008, 'eval_runtime': 11.8837, 'eval_samples_per_second': 147.597, 'eval_steps_per_second': 9.256, 'epoch': 3.81}
# {'loss': 1.001, 'learning_rate': 2.361684443828785e-05, 'epoch': 3.91}
# {'eval_loss': 7.258022785186768, 'eval_runtime': 11.8806, 'eval_samples_per_second': 147.636, 'eval_steps_per_second': 9.259, 'epoch': 3.91}
# {'eval_loss': 8.270719528198242, 'eval_runtime': 11.9139, 'eval_samples_per_second': 147.223, 'eval_steps_per_second': 9.233, 'epoch': 4.0}
# {'eval_loss': 6.18853235244751, 'eval_runtime': 11.8886, 'eval_samples_per_second': 147.537, 'eval_steps_per_second': 9.253, 'epoch': 4.1}
# {'eval_loss': 6.308024883270264, 'eval_runtime': 11.8545, 'eval_samples_per_second': 147.961, 'eval_steps_per_second': 9.279, 'epoch': 4.2}
# {'eval_loss': 7.095905780792236, 'eval_runtime': 11.8924, 'eval_samples_per_second': 147.489, 'eval_steps_per_second': 9.25, 'epoch': 4.3}
# {'loss': 0.847, 'learning_rate': 2.2577919379415434e-05, 'epoch': 4.39}
# {'eval_loss': 7.587064266204834, 'eval_runtime': 11.9271, 'eval_samples_per_second': 147.061, 'eval_steps_per_second': 9.223, 'epoch': 4.39}
# {'eval_loss': 6.75452184677124, 'eval_runtime': 11.9235, 'eval_samples_per_second': 147.104, 'eval_steps_per_second': 9.225, 'epoch': 4.49}
# {'eval_loss': 7.0227370262146, 'eval_runtime': 11.9222, 'eval_samples_per_second': 147.121, 'eval_steps_per_second': 9.227, 'epoch': 4.59}
# {'train_runtime': 1422.8696, 'train_samples_per_second': 86.297, 'train_steps_per_second': 10.795, 'train_loss': 1.1069260390261386, 'epoch': 4.59}
# {'eval_loss': 5.740498065948486, 'eval_runtime': 11.8668, 'eval_samples_per_second': 147.807, 'eval_steps_per_second': 9.27, 'epoch': 4.59}
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 5e-05, 'repeats': 0, 'weight_decay': 0.1}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 7.4325480461120605, 'eval_runtime': 11.917, 'eval_samples_per_second': 147.184, 'eval_steps_per_second': 9.23, 'epoch': 0.1}
# {'eval_loss': 8.202974319458008, 'eval_runtime': 11.9104, 'eval_samples_per_second': 147.266, 'eval_steps_per_second': 9.236, 'epoch': 0.2}
# {'eval_loss': 6.656482696533203, 'eval_runtime': 11.9153, 'eval_samples_per_second': 147.206, 'eval_steps_per_second': 9.232, 'epoch': 0.29}
# {'eval_loss': 8.458272933959961, 'eval_runtime': 11.902, 'eval_samples_per_second': 147.37, 'eval_steps_per_second': 9.242, 'epoch': 0.39}
# {'loss': 1.0601, 'learning_rate': 2.684381778741866e-05, 'epoch': 0.49}
# {'eval_loss': 8.51030158996582, 'eval_runtime': 11.913, 'eval_samples_per_second': 147.234, 'eval_steps_per_second': 9.234, 'epoch': 0.49}
# {'eval_loss': 6.830015182495117, 'eval_runtime': 11.9254, 'eval_samples_per_second': 147.081, 'eval_steps_per_second': 9.224, 'epoch': 0.59}
# {'eval_loss': 6.859786033630371, 'eval_runtime': 11.8897, 'eval_samples_per_second': 147.522, 'eval_steps_per_second': 9.252, 'epoch': 0.68}
# {'eval_loss': 7.246844291687012, 'eval_runtime': 11.9005, 'eval_samples_per_second': 147.389, 'eval_steps_per_second': 9.243, 'epoch': 0.78}
# {'eval_loss': 10.414210319519043, 'eval_runtime': 11.9189, 'eval_samples_per_second': 147.161, 'eval_steps_per_second': 9.229, 'epoch': 0.88}
# {'loss': 0.9888, 'learning_rate': 4.975065798587062e-05, 'epoch': 0.98}
# {'eval_loss': 6.025453090667725, 'eval_runtime': 11.9367, 'eval_samples_per_second': 146.941, 'eval_steps_per_second': 9.215, 'epoch': 0.98}
# {'eval_loss': 5.584110736846924, 'eval_runtime': 11.8907, 'eval_samples_per_second': 147.51, 'eval_steps_per_second': 9.251, 'epoch': 1.07}
# {'eval_loss': 5.698623180389404, 'eval_runtime': 11.8887, 'eval_samples_per_second': 147.536, 'eval_steps_per_second': 9.253, 'epoch': 1.17}
# {'eval_loss': 6.308150768280029, 'eval_runtime': 11.8691, 'eval_samples_per_second': 147.779, 'eval_steps_per_second': 9.268, 'epoch': 1.27}
# {'eval_loss': 7.421329975128174, 'eval_runtime': 11.9206, 'eval_samples_per_second': 147.141, 'eval_steps_per_second': 9.228, 'epoch': 1.37}
# ...
# {'eval_loss': 7.038326263427734, 'eval_runtime': 11.9327, 'eval_samples_per_second': 146.991, 'eval_steps_per_second': 9.218, 'epoch': 0.88}
# {'loss': 1.075, 'learning_rate': 6.964607286327745e-05, 'epoch': 0.98}
# {'eval_loss': 8.559680938720703, 'eval_runtime': 11.9511, 'eval_samples_per_second': 146.765, 'eval_steps_per_second': 9.204, 'epoch': 0.98}
# {'eval_loss': 7.219048500061035, 'eval_runtime': 11.8816, 'eval_samples_per_second': 147.623, 'eval_steps_per_second': 9.258, 'epoch': 1.07}
# {'eval_loss': 5.747544288635254, 'eval_runtime': 11.8981, 'eval_samples_per_second': 147.418, 'eval_steps_per_second': 9.245, 'epoch': 1.17}
# {'eval_loss': 6.912139892578125, 'eval_runtime': 11.8948, 'eval_samples_per_second': 147.46, 'eval_steps_per_second': 9.248, 'epoch': 1.27}
# {'eval_loss': 10.588237762451172, 'eval_runtime': 11.9222, 'eval_samples_per_second': 147.12, 'eval_steps_per_second': 9.226, 'epoch': 1.37}
# {'loss': 1.246, 'learning_rate': 6.722191439257514e-05, 'epoch': 1.46}
# {'eval_loss': 8.63613224029541, 'eval_runtime': 11.9463, 'eval_samples_per_second': 146.824, 'eval_steps_per_second': 9.208, 'epoch': 1.46}
# {'eval_loss': 8.38841724395752, 'eval_runtime': 11.9243, 'eval_samples_per_second': 147.094, 'eval_steps_per_second': 9.225, 'epoch': 1.56}
# {'eval_loss': 6.324434757232666, 'eval_runtime': 11.9305, 'eval_samples_per_second': 147.019, 'eval_steps_per_second': 9.22, 'epoch': 1.66}
# {'eval_loss': 7.58284854888916, 'eval_runtime': 11.945, 'eval_samples_per_second': 146.84, 'eval_steps_per_second': 9.209, 'epoch': 1.76}
# {'eval_loss': 8.606093406677246, 'eval_runtime': 11.9252, 'eval_samples_per_second': 147.083, 'eval_steps_per_second': 9.224, 'epoch': 1.86}
# {'loss': 1.5205, 'learning_rate': 6.479775592187284e-05, 'epoch': 1.95}
# {'eval_loss': 8.901033401489258, 'eval_runtime': 11.9449, 'eval_samples_per_second': 146.841, 'eval_steps_per_second': 9.209, 'epoch': 1.95}
# {'eval_loss': 6.646500110626221, 'eval_runtime': 11.9355, 'eval_samples_per_second': 146.956, 'eval_steps_per_second': 9.216, 'epoch': 2.05}
# {'eval_loss': 6.025613307952881, 'eval_runtime': 11.9383, 'eval_samples_per_second': 146.922, 'eval_steps_per_second': 9.214, 'epoch': 2.15}
# {'eval_loss': 7.890278339385986, 'eval_runtime': 11.944, 'eval_samples_per_second': 146.852, 'eval_steps_per_second': 9.21, 'epoch': 2.25}
# {'eval_loss': 7.6358184814453125, 'eval_runtime': 11.9096, 'eval_samples_per_second': 147.277, 'eval_steps_per_second': 9.236, 'epoch': 2.34}
# {'loss': 1.5287, 'learning_rate': 6.237844576811192e-05, 'epoch': 2.44}
# {'eval_loss': 5.862237930297852, 'eval_runtime': 11.8934, 'eval_samples_per_second': 147.477, 'eval_steps_per_second': 9.249, 'epoch': 2.44}
# {'eval_loss': 10.49759292602539, 'eval_runtime': 11.9062, 'eval_samples_per_second': 147.318, 'eval_steps_per_second': 9.239, 'epoch': 2.54}
# {'eval_loss': 7.104963302612305, 'eval_runtime': 11.9297, 'eval_samples_per_second': 147.028, 'eval_steps_per_second': 9.221, 'epoch': 2.64}
# {'eval_loss': 6.654000759124756, 'eval_runtime': 11.9543, 'eval_samples_per_second': 146.726, 'eval_steps_per_second': 9.202, 'epoch': 2.73}
# {'eval_loss': 7.22669792175293, 'eval_runtime': 11.9372, 'eval_samples_per_second': 146.935, 'eval_steps_per_second': 9.215, 'epoch': 2.83}
# {'loss': 1.6573, 'learning_rate': 5.995428729740961e-05, 'epoch': 2.93}
# {'eval_loss': 6.775550842285156, 'eval_runtime': 11.9281, 'eval_samples_per_second': 147.047, 'eval_steps_per_second': 9.222, 'epoch': 2.93}
# {'eval_loss': 6.320174217224121, 'eval_runtime': 11.927, 'eval_samples_per_second': 147.061, 'eval_steps_per_second': 9.223, 'epoch': 3.03}
# {'eval_loss': 6.667595386505127, 'eval_runtime': 11.9215, 'eval_samples_per_second': 147.129, 'eval_steps_per_second': 9.227, 'epoch': 3.12}
# {'eval_loss': 6.42321252822876, 'eval_runtime': 11.9218, 'eval_samples_per_second': 147.126, 'eval_steps_per_second': 9.227, 'epoch': 3.22}
# {'eval_loss': 7.44500732421875, 'eval_runtime': 11.9448, 'eval_samples_per_second': 146.842, 'eval_steps_per_second': 9.209, 'epoch': 3.32}
# {'loss': 1.2065, 'learning_rate': 5.753012882670729e-05, 'epoch': 3.42}
# {'eval_loss': 7.440646648406982, 'eval_runtime': 11.8842, 'eval_samples_per_second': 147.591, 'eval_steps_per_second': 9.256, 'epoch': 3.42}
# {'eval_loss': 5.941230297088623, 'eval_runtime': 11.8774, 'eval_samples_per_second': 147.676, 'eval_steps_per_second': 9.261, 'epoch': 3.52}
# {'train_runtime': 1092.0147, 'train_samples_per_second': 112.444, 'train_steps_per_second': 14.066, 'train_loss': 1.3190049934387207, 'epoch': 3.52}
# {'eval_loss': 5.631250858306885, 'eval_runtime': 11.8326, 'eval_samples_per_second': 148.235, 'eval_steps_per_second': 9.296, 'epoch': 3.52}
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 7e-05, 'repeats': 0, 'weight_decay': 0.01}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 7.3956098556518555, 'eval_runtime': 11.9316, 'eval_samples_per_second': 147.004, 'eval_steps_per_second': 9.219, 'epoch': 0.1}
# {'eval_loss': 8.37522029876709, 'eval_runtime': 11.9277, 'eval_samples_per_second': 147.052, 'eval_steps_per_second': 9.222, 'epoch': 0.2}
# {'eval_loss': 9.507780075073242, 'eval_runtime': 11.9483, 'eval_samples_per_second': 146.799, 'eval_steps_per_second': 9.206, 'epoch': 0.29}
# {'eval_loss': 8.547837257385254, 'eval_runtime': 11.8818, 'eval_samples_per_second': 147.621, 'eval_steps_per_second': 9.258, 'epoch': 0.39}
# {'loss': 1.0188, 'learning_rate': 3.7581344902386116e-05, 'epoch': 0.49}
# {'eval_loss': 7.255034446716309, 'eval_runtime': 11.8548, 'eval_samples_per_second': 147.957, 'eval_steps_per_second': 9.279, 'epoch': 0.49}
# {'eval_loss': 5.831875324249268, 'eval_runtime': 11.8808, 'eval_samples_per_second': 147.633, 'eval_steps_per_second': 9.259, 'epoch': 0.59}
# {'eval_loss': 7.9372663497924805, 'eval_runtime': 11.9472, 'eval_samples_per_second': 146.813, 'eval_steps_per_second': 9.207, 'epoch': 0.68}
# {'eval_loss': 5.760732173919678, 'eval_runtime': 11.9324, 'eval_samples_per_second': 146.994, 'eval_steps_per_second': 9.219, 'epoch': 0.78}
# {'eval_loss': 7.899389743804932, 'eval_runtime': 11.9098, 'eval_samples_per_second': 147.274, 'eval_steps_per_second': 9.236, 'epoch': 0.88}
# {'loss': 1.2323, 'learning_rate': 6.964607286327745e-05, 'epoch': 0.98}
# {'eval_loss': 8.035688400268555, 'eval_runtime': 11.9405, 'eval_samples_per_second': 146.895, 'eval_steps_per_second': 9.212, 'epoch': 0.98}
# {'eval_loss': 7.269239902496338, 'eval_runtime': 11.9511, 'eval_samples_per_second': 146.765, 'eval_steps_per_second': 9.204, 'epoch': 1.07}
# {'eval_loss': 5.59572696685791, 'eval_runtime': 11.9197, 'eval_samples_per_second': 147.152, 'eval_steps_per_second': 9.228, 'epoch': 1.17}
# {'eval_loss': 6.605605602264404, 'eval_runtime': 11.9433, 'eval_samples_per_second': 146.86, 'eval_steps_per_second': 9.21, 'epoch': 1.27}
# {'eval_loss': 9.50637149810791, 'eval_runtime': 11.9499, 'eval_samples_per_second': 146.78, 'eval_steps_per_second': 9.205, 'epoch': 1.37}
# {'loss': 1.1158, 'learning_rate': 6.722191439257514e-05, 'epoch': 1.46}
# {'eval_loss': 8.459676742553711, 'eval_runtime': 11.9082, 'eval_samples_per_second': 147.293, 'eval_steps_per_second': 9.237, 'epoch': 1.46}
# {'eval_loss': 7.888655662536621, 'eval_runtime': 11.9238, 'eval_samples_per_second': 147.1, 'eval_steps_per_second': 9.225, 'epoch': 1.56}
# {'eval_loss': 6.272523403167725, 'eval_runtime': 11.9382, 'eval_samples_per_second': 146.923, 'eval_steps_per_second': 9.214, 'epoch': 1.66}
# {'eval_loss': 6.443808078765869, 'eval_runtime': 11.9225, 'eval_samples_per_second': 147.117, 'eval_steps_per_second': 9.226, 'epoch': 1.76}
# {'eval_loss': 7.9573073387146, 'eval_runtime': 11.9449, 'eval_samples_per_second': 146.841, 'eval_steps_per_second': 9.209, 'epoch': 1.86}
# {'loss': 1.5121, 'learning_rate': 6.479775592187284e-05, 'epoch': 1.95}
# {'eval_loss': 8.020488739013672, 'eval_runtime': 11.916, 'eval_samples_per_second': 147.197, 'eval_steps_per_second': 9.231, 'epoch': 1.95}
# {'eval_loss': 8.447534561157227, 'eval_runtime': 11.9059, 'eval_samples_per_second': 147.322, 'eval_steps_per_second': 9.239, 'epoch': 2.05}
# {'eval_loss': 5.888902187347412, 'eval_runtime': 11.9278, 'eval_samples_per_second': 147.051, 'eval_steps_per_second': 9.222, 'epoch': 2.15}
# {'eval_loss': 7.1691741943359375, 'eval_runtime': 11.9169, 'eval_samples_per_second': 147.186, 'eval_steps_per_second': 9.231, 'epoch': 2.25}
# {'eval_loss': 6.30549430847168, 'eval_runtime': 11.8616, 'eval_samples_per_second': 147.872, 'eval_steps_per_second': 9.274, 'epoch': 2.34}
# {'loss': 1.5222, 'learning_rate': 6.237844576811192e-05, 'epoch': 2.44}
# {'eval_loss': 6.51947546005249, 'eval_runtime': 11.8732, 'eval_samples_per_second': 147.728, 'eval_steps_per_second': 9.265, 'epoch': 2.44}
# {'eval_loss': 7.184014797210693, 'eval_runtime': 11.9094, 'eval_samples_per_second': 147.278, 'eval_steps_per_second': 9.236, 'epoch': 2.54}
# {'eval_loss': 6.412360668182373, 'eval_runtime': 11.9366, 'eval_samples_per_second': 146.943, 'eval_steps_per_second': 9.215, 'epoch': 2.64}
# {'eval_loss': 6.676029682159424, 'eval_runtime': 11.8356, 'eval_samples_per_second': 148.198, 'eval_steps_per_second': 9.294, 'epoch': 2.73}
# {'eval_loss': 6.814244747161865, 'eval_runtime': 11.8039, 'eval_samples_per_second': 148.595, 'eval_steps_per_second': 9.319, 'epoch': 2.83}
# {'loss': 1.6581, 'learning_rate': 5.995428729740961e-05, 'epoch': 2.93}
# {'eval_loss': 6.0052690505981445, 'eval_runtime': 11.9101, 'eval_samples_per_second': 147.27, 'eval_steps_per_second': 9.236, 'epoch': 2.93}
# {'eval_loss': 8.006609916687012, 'eval_runtime': 11.9524, 'eval_samples_per_second': 146.748, 'eval_steps_per_second': 9.203, 'epoch': 3.03}
# {'eval_loss': 6.838427543640137, 'eval_runtime': 11.9041, 'eval_samples_per_second': 147.344, 'eval_steps_per_second': 9.24, 'epoch': 3.12}
# {'eval_loss': 7.7400054931640625, 'eval_runtime': 11.9027, 'eval_samples_per_second': 147.362, 'eval_steps_per_second': 9.242, 'epoch': 3.22}
# {'eval_loss': 7.991427421569824, 'eval_runtime': 11.915, 'eval_samples_per_second': 147.21, 'eval_steps_per_second': 9.232, 'epoch': 3.32}
# {'loss': 1.1778, 'learning_rate': 5.753012882670729e-05, 'epoch': 3.42}
# {'eval_loss': 7.683418273925781, 'eval_runtime': 11.9328, 'eval_samples_per_second': 146.99, 'eval_steps_per_second': 9.218, 'epoch': 3.42}
# {'eval_loss': 6.628488540649414, 'eval_runtime': 11.9093, 'eval_samples_per_second': 147.28, 'eval_steps_per_second': 9.237, 'epoch': 3.52}
# {'eval_loss': 6.899399757385254, 'eval_runtime': 11.8926, 'eval_samples_per_second': 147.486, 'eval_steps_per_second': 9.249, 'epoch': 3.61}
# {'eval_loss': 7.654462814331055, 'eval_runtime': 11.9177, 'eval_samples_per_second': 147.176, 'eval_steps_per_second': 9.23, 'epoch': 3.71}
# {'eval_loss': 6.327577590942383, 'eval_runtime': 11.918, 'eval_samples_per_second': 147.172, 'eval_steps_per_second': 9.23, 'epoch': 3.81}
# {'loss': 1.1019, 'learning_rate': 5.510597035600498e-05, 'epoch': 3.91}
# {'eval_loss': 7.085916996002197, 'eval_runtime': 11.9398, 'eval_samples_per_second': 146.904, 'eval_steps_per_second': 9.213, 'epoch': 3.91}
# {'eval_loss': 9.10307788848877, 'eval_runtime': 11.9126, 'eval_samples_per_second': 147.239, 'eval_steps_per_second': 9.234, 'epoch': 4.0}
# {'eval_loss': 5.95258092880249, 'eval_runtime': 11.9219, 'eval_samples_per_second': 147.125, 'eval_steps_per_second': 9.227, 'epoch': 4.1}
# {'train_runtime': 1273.5228, 'train_samples_per_second': 96.418, 'train_steps_per_second': 12.061, 'train_loss': 1.2771492295038132, 'epoch': 4.1}
# {'eval_loss': 5.59572696685791, 'eval_runtime': 11.8791, 'eval_samples_per_second': 147.655, 'eval_steps_per_second': 9.26, 'epoch': 4.1}
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 9e-05, 'repeats': 0, 'weight_decay': 0.1}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 7.730625629425049, 'eval_runtime': 11.9588, 'eval_samples_per_second': 146.67, 'eval_steps_per_second': 9.198, 'epoch': 0.1}
# {'eval_loss': 7.795590877532959, 'eval_runtime': 11.8908, 'eval_samples_per_second': 147.509, 'eval_steps_per_second': 9.251, 'epoch': 0.2}
# {'eval_loss': 7.932498455047607, 'eval_runtime': 11.886, 'eval_samples_per_second': 147.569, 'eval_steps_per_second': 9.255, 'epoch': 0.29}
# {'eval_loss': 10.446456909179688, 'eval_runtime': 11.8804, 'eval_samples_per_second': 147.639, 'eval_steps_per_second': 9.259, 'epoch': 0.39}
# {'loss': 1.044, 'learning_rate': 4.831887201735358e-05, 'epoch': 0.49}
# {'eval_loss': 7.606698036193848, 'eval_runtime': 11.9123, 'eval_samples_per_second': 147.243, 'eval_steps_per_second': 9.234, 'epoch': 0.49}
# {'eval_loss': 6.030874729156494, 'eval_runtime': 11.9705, 'eval_samples_per_second': 146.527, 'eval_steps_per_second': 9.189, 'epoch': 0.59}
# {'eval_loss': 6.094177722930908, 'eval_runtime': 11.9491, 'eval_samples_per_second': 146.789, 'eval_steps_per_second': 9.206, 'epoch': 0.68}
# {'eval_loss': 9.626574516296387, 'eval_runtime': 11.8965, 'eval_samples_per_second': 147.439, 'eval_steps_per_second': 9.246, 'epoch': 0.78}
# {'eval_loss': 5.810028076171875, 'eval_runtime': 11.8198, 'eval_samples_per_second': 148.395, 'eval_steps_per_second': 9.306, 'epoch': 0.88}
# {'loss': 1.4437, 'learning_rate': 8.955118437456711e-05, 'epoch': 0.98}
# {'eval_loss': 5.843968391418457, 'eval_runtime': 11.868, 'eval_samples_per_second': 147.793, 'eval_steps_per_second': 9.269, 'epoch': 0.98}
# {'eval_loss': 8.904291152954102, 'eval_runtime': 11.9252, 'eval_samples_per_second': 147.083, 'eval_steps_per_second': 9.224, 'epoch': 1.07}
# {'eval_loss': 5.901662349700928, 'eval_runtime': 11.9191, 'eval_samples_per_second': 147.159, 'eval_steps_per_second': 9.229, 'epoch': 1.17}
# {'eval_loss': 9.143710136413574, 'eval_runtime': 11.9099, 'eval_samples_per_second': 147.272, 'eval_steps_per_second': 9.236, 'epoch': 1.27}
# {'eval_loss': 10.245580673217773, 'eval_runtime': 11.9187, 'eval_samples_per_second': 147.163, 'eval_steps_per_second': 9.229, 'epoch': 1.37}
# {'loss': 1.3109, 'learning_rate': 8.643440919794986e-05, 'epoch': 1.46}
# {'eval_loss': 8.373686790466309, 'eval_runtime': 11.9201, 'eval_samples_per_second': 147.147, 'eval_steps_per_second': 9.228, 'epoch': 1.46}
# {'eval_loss': 9.221802711486816, 'eval_runtime': 11.9435, 'eval_samples_per_second': 146.858, 'eval_steps_per_second': 9.21, 'epoch': 1.56}
# {'eval_loss': 7.543959140777588, 'eval_runtime': 11.9337, 'eval_samples_per_second': 146.979, 'eval_steps_per_second': 9.218, 'epoch': 1.66}
# {'eval_loss': 6.0626397132873535, 'eval_runtime': 11.9294, 'eval_samples_per_second': 147.031, 'eval_steps_per_second': 9.221, 'epoch': 1.76}
# {'eval_loss': 9.006640434265137, 'eval_runtime': 11.9135, 'eval_samples_per_second': 147.228, 'eval_steps_per_second': 9.233, 'epoch': 1.86}
# {'loss': 1.6956, 'learning_rate': 8.33176340213326e-05, 'epoch': 1.95}
# {'eval_loss': 9.019012451171875, 'eval_runtime': 11.8982, 'eval_samples_per_second': 147.417, 'eval_steps_per_second': 9.245, 'epoch': 1.95}
# {'eval_loss': 8.894363403320312, 'eval_runtime': 11.9251, 'eval_samples_per_second': 147.085, 'eval_steps_per_second': 9.224, 'epoch': 2.05}
# {'eval_loss': 6.728553295135498, 'eval_runtime': 11.9174, 'eval_samples_per_second': 147.18, 'eval_steps_per_second': 9.23, 'epoch': 2.15}
# {'eval_loss': 6.1128034591674805, 'eval_runtime': 11.8787, 'eval_samples_per_second': 147.659, 'eval_steps_per_second': 9.26, 'epoch': 2.25}
# {'eval_loss': 6.533841609954834, 'eval_runtime': 11.86, 'eval_samples_per_second': 147.892, 'eval_steps_per_second': 9.275, 'epoch': 2.34}

# %%
import torch
print(torch.__version__)
# Out:
# 1.11.0+cu102

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#Test set performance
best_model = DistilBertWithTabular.from_pretrained(FINAL_MODEL_PATH)
trainer_best_model = Trainer(model=best_model)

predictions = trainer_best_model.predict(test_dataset)
# Out:
# ***** Running Prediction *****
#   Num examples = 1754
#   Batch size = 8

# %%
preds = predictions.predictions[0].flatten() 
labels = predictions.label_ids

if TARGET_COL == 'revenue_worldwide_BOM':
    preds = np.expm1(preds)
    labels = np.expm1(labels)


mse = ((preds-labels)**2).mean()
mae = (np.abs(preds-labels)).mean()
errors = {'MAE':mae,'MSE':mse,'RMSE':np.sqrt(mse)}
pd.DataFrame([errors]).to_csv(TEST_PERFORMANCE_PATH,
                              index=False)

# %%
len(predictions.predictions[1][0][0])
# Out:
# 773

# %%
predictions.predictions[0]
# Out:
# array([[5.3603134],
#        [6.1881814],
#        [6.5145   ],
#        ...,
#        [7.1097665],
#        [5.7504053],
#        [5.5580487]], dtype=float32)
