# %%
#!pip install -U transformers
#!pip install -U datasets
#!pip install optuna
import os
import sys
HOME = os.path.abspath('..')
sys.path.append(HOME)
os.chdir(HOME)
import pandas as pd
#!pip install transformers
from transformers import RobertaConfig, RobertaModel,RobertaForSequenceClassification, Trainer,AutoModelForSequenceClassification, EarlyStoppingCallback 
from transformers import AutoTokenizer
from transformers.models.roberta import RobertaPreTrainedModel
from sklearn.preprocessing import StandardScaler
import torch
from torch import nn
from transformers import TrainingArguments
import glob
import optuna
from itertools import product
import numpy as np
from pprint import pprint

# %%
MODEL_NAME =  "distilbert-base-uncased" #"roberta-base" 
TARGET_COL = 'revenue_worldwide_BOM'#'averageRating'#
MODEL_FOLDER = 'only_text_features'#
text_input_col = 'text_input'
CATEGORIES_AS_TEXT = False
NUMERIC_AS_TEXT = False
DATE_AS_TEXT = False
ADJUST_INFLATION = False
USE_COLUMN_NAMES = False
COLAB = False
DEBUG = False

FINAL_MODEL_NAME = f"{MODEL_NAME}-{TARGET_COL}"

if ADJUST_INFLATION:
    FINAL_MODEL_NAME+='-inflation_adjusted'
    
if USE_COLUMN_NAMES:
    FINAL_MODEL_NAME+='-with_column_names'
    

FINAL_MODEL_PATH = f'models/{MODEL_FOLDER}/{FINAL_MODEL_NAME}'
TRIALS_DF_PATH = f'models/{MODEL_FOLDER}/{FINAL_MODEL_NAME}_hparams_trials.csv'
TEST_PERFORMANCE_PATH = f'models/{MODEL_FOLDER}/{FINAL_MODEL_NAME}_test_stats_best_model.csv'
    
if USE_COLUMN_NAMES:
    assert CATEGORIES_AS_TEXT|NUMERIC_AS_TEXT|DATE_AS_TEXT, "can't use column names as text if there are no columns to treat as text!"
    
print('Final model name: ',FINAL_MODEL_NAME)
print('Saving at: ',MODEL_FOLDER)


if COLAB == True:
  if not os.path.exists('data'):
    os.mkdir('data')
  if not os.path.exists('data/processed'):
    os.mkdir('data/processed')

  drive.mount('/content/gdrive/')
  for filename in glob.glob(os.path.join('gdrive/MyDrive/atdl', '*.*')):
      shutil.copy(filename, 'data/processed')
# Out:
# Final model name:  distilbert-base-uncased-revenue_worldwide_BOM
# Saving at:  only_text_features

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

class IMDbDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

def process_text_data(data_:pd.DataFrame,text_col,padding ="max_length", truncation = True, na_filler = ""):

    '''
    
    '''
    data = data_.copy()
    data[text_col] = data[text_col].fillna(na_filler)
    encodings = tokenizer(data[text_col].tolist(), padding=padding, truncation=truncation)
    return encodings
    

def columns_to_single_text(df,
                           cols_to_transform,
                           use_column_names = False,
                           new_col_name = 'text_input',
                           sep = tokenizer.sep_token,
                           nan_replacement = tokenizer.unk_token):

  '''
  
  Creates a new column called new_col_name with with all columns in cols_to_transform concatenated into a single text
  '''
  
  temp = df[cols_to_transform].astype(str).replace('nan',nan_replacement)


  if use_column_names:
    for col in cols_to_transform:
        temp[col] = f'{col}: '+temp[col]
        
  df[new_col_name] = temp.agg(f' {sep} '.join, axis=1)


class NAFiller:

  def __init__(self,train):
    self.train = train

  def fit(self,column = 'Budget',groupby=['top_genre','top_country']):
    self.mapping = self.train.groupby(groupby)[column].median().reset_index()
    self.mapping = self.mapping.rename(columns={column:'na_filler'})
    self.median = self.train[column].median()
    self.column=column


  def transform(self,test,round = False):
    self.na_filler = test.merge(self.mapping,how='left')['na_filler']
    self.na_filler = self.na_filler.fillna(self.median)

    test[self.column] = test[self.column].reset_index(drop=True).fillna(self.na_filler).values

    if round:
      test[self.column] = test[self.column].round().astype(int)
      


  def fit_transform(self,test,column = 'Budget',groupby=['top_genre','top_country']):
    self.fit(column,groupby)
    self.transform()
    self.column=column
        

def create_dataset_split(split,
                         text_cols,
                         text_input_col,
                         TARGET_COL,
                         use_column_names = False,
                         new_col_name = 'text_input',
                         sep = tokenizer.sep_token,
                         nan_replacement = tokenizer.unk_token):
    
  if TARGET_COL == 'revenue_worldwide_BOM':
    split[TARGET_COL] = np.log1p(split[TARGET_COL])
    print('log transforming target')

  #If all columns in text_cols are combined into a single text. A n
  columns_to_single_text(split,text_cols,
                         use_column_names,
                         new_col_name,
                         sep,
                         nan_replacement)

  #Get split encodings
  split_encodings = process_text_data(split,text_input_col)
    
  #get labels
  split_labels = split[TARGET_COL].tolist()

  #Create dataset objects
  split_dataset = IMDbDataset(split_encodings, split_labels)

  return split_dataset


def get_model():
    return get_model_by_name(MODEL_NAME)

def get_model_by_name(model_name):
    return AutoModelForSequenceClassification.from_pretrained(model_name,
                                                         problem_type='regression',
                                                         num_labels=1
                                                        )       


def date_to_season(doy):
    doy = doy.dayofyear
    # "day of year" ranges for the northern hemisphere
    spring = range(80, 172)
    summer = range(172, 264)
    fall = range(264, 355)
    # winter = everything else

    if doy in spring:
      season = 1 #'spring'
    elif doy in summer:
      season = 2 #'summer'
    elif doy in fall:
      season = 3 #'fall'
    else:
      season = 4 #'winter'
    return season

# %%
all_cols =  ['Budget',
             'averageRating',
             'cast',
             'countries',
             'director',
             'genres',
             'imdb_id',
             'languages',
             'overview',
             'production companies',
             'release_date',
             'revenue_worldwide_BOM',
             'runtimeMinutes',
             'title']

train_ids = pd.read_csv('data/processed/train.csv',usecols=['imdb_id'])['imdb_id'].tolist()
val_ids = pd.read_csv('data/processed/val.csv',usecols=['imdb_id'])['imdb_id'].tolist()
test_ids = pd.read_csv('data/processed/test.csv',usecols=['imdb_id'])['imdb_id'].tolist()
df = pd.read_csv('data/processed/df.csv',usecols = all_cols,parse_dates=['release_date']).sample(frac=1,random_state=42) #shuffle


#Additional auxilary columns
df['top_genre'] = df['genres'].apply(lambda x: x.split(', ')[0])
df['top_country'] = df['countries'].apply(lambda x: x.split(', ')[0] if isinstance(x,str) else x)

df['year'] = df['release_date'].dt.year
df['month'] = df['release_date'].dt.month
df['day'] = df['release_date'].dt.day
df['season'] = df['release_date'].apply(date_to_season)
df['dayofweek'] = df['release_date'].dt.dayofweek


categoric_cols = ['cast',
                  'countries',
                  'director',
                  'genres',
                  'languages',
                  'production companies']

text_cols = ['title','overview']                  
date_cols = ['release_date']
numeric_cols = ['Budget',
                'runtimeMinutes'
               ] 

if (not DATE_AS_TEXT): #If date is not as text, include numeri date features
    numeric_cols += ['year',
                     'month',
                     'day',
                     'season',
                     'dayofweek']

                

if CATEGORIES_AS_TEXT:
  text_cols+=categoric_cols

if NUMERIC_AS_TEXT:
  text_cols+=numeric_cols

if DATE_AS_TEXT:
  text_cols+=date_cols


df[categoric_cols] = df[categoric_cols].apply(lambda x: x.str.replace('|',', '),axis=0) #Change pipe to comma, its more meaningful
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:65: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df['runtimeMinutes'] = pd.to_numeric(df['runtimeMinutes'],errors='coerce')

# %%
#Create splits
if DEBUG:
    train = df[df['imdb_id'].isin(train_ids)].sample(frac=0.2)
    val = df[df['imdb_id'].isin(val_ids)].sample(frac=0.2)
    test = df[df['imdb_id'].isin(test_ids)]
else:
    train = df[df['imdb_id'].isin(train_ids)]
    val = df[df['imdb_id'].isin(val_ids)]
    test = df[df['imdb_id'].isin(test_ids)]



#Fill na in some columns with statistics
naf = NAFiller(train)
sc = StandardScaler()

for col in numeric_cols:
    naf.fit(column = col,groupby=['top_genre','top_country'])
    naf.transform(train,round=True)
    naf.transform(val,round=True)
    naf.transform(test,round=True)

if not NUMERIC_AS_TEXT:
    for col in numeric_cols:
        train[numeric_cols] = sc.fit_transform(train[numeric_cols])
        val[numeric_cols] = sc.transform(val[numeric_cols])
        test[numeric_cols] = sc.transform(test[numeric_cols])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
train_dataset=create_dataset_split(train,text_cols,text_input_col,TARGET_COL,USE_COLUMN_NAMES)
val_dataset=create_dataset_split(val,text_cols,text_input_col,TARGET_COL,USE_COLUMN_NAMES)
test_dataset=create_dataset_split(test,text_cols,text_input_col,TARGET_COL,USE_COLUMN_NAMES)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# log transforming target
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# log transforming target
# log transforming target

# %%
#Example of input to language model
train['text_input'].iloc[15]
# Out:
# "Dedication [SEP] A modern love story in which a misanthropic, emotionally complex author of a hit children's book is forced to team with a beautiful illustrator after his best friend and collaborator passes away. As Henry struggles with letting go of the ghosts of love and life, he discovers that sometimes you have to take a gamble at life to find love."

# %%
import csv
class DictWriter:
    
    def __init__(self,file_path,field_names):
        self.field_names = field_names
        self.file_path = file_path
        self.create_file() #Crerate file if it doesnt exist.
        
    def create_file(self):
        if not os.path.exists(self.file_path):
            print('creating file')
            f = open(self.file_path, 'w')
            w = csv.DictWriter(f, field_names)
            w.writeheader()
            f.close()
        else:
            print('file already exist. Will append rows to it.')
            
    def add_rows(self,rows):  
        with open(self.file_path, 'a') as f:
            w = csv.DictWriter(f,self.field_names)
            for r in rows:    
                w.writerow(r)

# %%
epochs = 15
patience = 2 if DEBUG else 30
callbacks=[EarlyStoppingCallback(early_stopping_patience=patience)]
eval_steps = 50 if DEBUG else 100


hparams = {'batch_size' : [8,16,32],
           'learning_rate' : [7e-6,9e-6,1e-5, 2e-5, 3e-5,5e-5,7e-5,3e-4],
           'weight_decay' : [0.1,0.01],
           'repeats': range(1)}

combs = list(product(*[range(len(i)) for i in list(hparams.values())]))
scores = np.zeros([len(i) for i in list(hparams.values())])

#trials_df_rows = []

field_names = list(hparams.keys()) + ['score']
dw = DictWriter(TRIALS_DF_PATH,field_names)

currernt_trials_df = pd.read_csv(TRIALS_DF_PATH) #This can be empty or not.
done_trials = currernt_trials_df.drop('score',axis=1).to_dict(orient='records') #empty list or not
best_score = min(float('inf'),currernt_trials_df['score'].min())

print(f'current best val score = {best_score}')

for idx,comb_indexes in enumerate(combs):
    comb_values = {name:val[idx] for name,val,idx in zip(hparams.keys(),hparams.values(),comb_indexes)}
    
    if comb_values not in done_trials: #Check if trial alrready exists. If it does, skip.
        print('training with following hparams:')
        pprint(comb_values)

        training_args = TrainingArguments(output_dir=f"{MODEL_NAME}-{TARGET_COL}",
                                          per_device_train_batch_size = comb_values['batch_size'],
                                          learning_rate=comb_values['learning_rate'],
                                          weight_decay=comb_values['weight_decay'],
                                          seed = 42,
                                          fp16=True,
                                          per_device_eval_batch_size = 16,
                                          warmup_ratio=0.06,
                                          num_train_epochs = epochs,
                                          evaluation_strategy = "steps",
                                          save_strategy = "steps",
                                          load_best_model_at_end=True,
                                          eval_steps = eval_steps,
                                          save_steps = eval_steps,
                                          save_total_limit = 1,
                                          log_level = 'error',
                                          disable_tqdm = True

                                        )

        trainer = Trainer(
            model_init=get_model,
            args=training_args,
            train_dataset=train_dataset,
            eval_dataset=val_dataset,
            callbacks = callbacks
        )
        


        trainer.train()

        score = trainer.evaluate()['eval_loss']

        scores[tuple(comb_indexes)] = score #outdated

        comb_values['score'] = score

        dw.add_rows([comb_values]) #Append to dataframe

        #trials_df_rows.append(comb_values)

        if score<best_score:
            print(f'got a better model, with score {np.round(score,4)} saving...')
            best_score = score
            trainer.save_model(FINAL_MODEL_PATH)
            
            print('saved')
    else:
        print('skipping trial because already exists')


#trials_df = pd.DataFrame(trials_df_rows)
#trials_df.to_csv(f'models/{MODEL_FOLDER}/hparams_trials.csv',index=False)
# Out:
# file already exist. Will append rows to it.
# current best val score = 9.857601165771484
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 7e-06, 'repeats': 0, 'weight_decay': 0.1}
# {'eval_loss': 189.0709686279297, 'eval_runtime': 11.0238, 'eval_samples_per_second': 159.111, 'eval_steps_per_second': 9.978, 'epoch': 0.1}
# {'eval_loss': 164.88433837890625, 'eval_runtime': 11.9538, 'eval_samples_per_second': 146.732, 'eval_steps_per_second': 9.202, 'epoch': 0.2}
# {'eval_loss': 125.94782257080078, 'eval_runtime': 11.0714, 'eval_samples_per_second': 158.426, 'eval_steps_per_second': 9.936, 'epoch': 0.29}
# {'eval_loss': 92.71820068359375, 'eval_runtime': 11.1205, 'eval_samples_per_second': 157.726, 'eval_steps_per_second': 9.892, 'epoch': 0.39}
# {'loss': 172.9974, 'learning_rate': 3.74295010845987e-06, 'epoch': 0.49}
# {'eval_loss': 70.64097595214844, 'eval_runtime': 11.3083, 'eval_samples_per_second': 155.107, 'eval_steps_per_second': 9.727, 'epoch': 0.49}
# {'eval_loss': 51.825435638427734, 'eval_runtime': 11.117, 'eval_samples_per_second': 157.776, 'eval_steps_per_second': 9.895, 'epoch': 0.59}
# {'eval_loss': 35.36429214477539, 'eval_runtime': 11.1104, 'eval_samples_per_second': 157.87, 'eval_steps_per_second': 9.901, 'epoch': 0.68}
# {'eval_loss': 22.08063316345215, 'eval_runtime': 11.1735, 'eval_samples_per_second': 156.979, 'eval_steps_per_second': 9.845, 'epoch': 0.78}
# {'eval_loss': 14.104815483093262, 'eval_runtime': 11.1585, 'eval_samples_per_second': 157.19, 'eval_steps_per_second': 9.858, 'epoch': 0.88}
# {'loss': 42.8636, 'learning_rate': 6.965576949716027e-06, 'epoch': 0.98}
# {'eval_loss': 13.385558128356934, 'eval_runtime': 11.1127, 'eval_samples_per_second': 157.838, 'eval_steps_per_second': 9.899, 'epoch': 0.98}
# {'eval_loss': 14.267038345336914, 'eval_runtime': 11.2275, 'eval_samples_per_second': 156.224, 'eval_steps_per_second': 9.797, 'epoch': 1.07}
# {'eval_loss': 15.497576713562012, 'eval_runtime': 11.1449, 'eval_samples_per_second': 157.382, 'eval_steps_per_second': 9.87, 'epoch': 1.17}
# {'eval_loss': 13.823456764221191, 'eval_runtime': 11.1016, 'eval_samples_per_second': 157.995, 'eval_steps_per_second': 9.908, 'epoch': 1.27}
# {'eval_loss': 15.45150375366211, 'eval_runtime': 11.2239, 'eval_samples_per_second': 156.274, 'eval_steps_per_second': 9.801, 'epoch': 1.37}
# {'loss': 9.2901, 'learning_rate': 6.723161102645796e-06, 'epoch': 1.46}
# {'eval_loss': 12.157218933105469, 'eval_runtime': 11.2193, 'eval_samples_per_second': 156.338, 'eval_steps_per_second': 9.805, 'epoch': 1.46}
# {'eval_loss': 13.631879806518555, 'eval_runtime': 11.1538, 'eval_samples_per_second': 157.255, 'eval_steps_per_second': 9.862, 'epoch': 1.56}
# {'eval_loss': 12.065312385559082, 'eval_runtime': 11.1613, 'eval_samples_per_second': 157.15, 'eval_steps_per_second': 9.855, 'epoch': 1.66}
# {'eval_loss': 13.543233871459961, 'eval_runtime': 11.1935, 'eval_samples_per_second': 156.697, 'eval_steps_per_second': 9.827, 'epoch': 1.76}
# {'eval_loss': 11.638304710388184, 'eval_runtime': 11.1994, 'eval_samples_per_second': 156.615, 'eval_steps_per_second': 9.822, 'epoch': 1.86}
# {'loss': 8.5097, 'learning_rate': 6.480745255575564e-06, 'epoch': 1.95}
# {'eval_loss': 10.839303016662598, 'eval_runtime': 11.2112, 'eval_samples_per_second': 156.45, 'eval_steps_per_second': 9.812, 'epoch': 1.95}
# {'eval_loss': 12.822970390319824, 'eval_runtime': 11.265, 'eval_samples_per_second': 155.704, 'eval_steps_per_second': 9.765, 'epoch': 2.05}
# {'eval_loss': 12.577178955078125, 'eval_runtime': 11.192, 'eval_samples_per_second': 156.719, 'eval_steps_per_second': 9.828, 'epoch': 2.15}
# {'eval_loss': 13.523597717285156, 'eval_runtime': 11.1988, 'eval_samples_per_second': 156.624, 'eval_steps_per_second': 9.822, 'epoch': 2.25}
# {'eval_loss': 12.080251693725586, 'eval_runtime': 11.1963, 'eval_samples_per_second': 156.659, 'eval_steps_per_second': 9.825, 'epoch': 2.34}
# {'loss': 7.4039, 'learning_rate': 6.238329408505333e-06, 'epoch': 2.44}
# {'eval_loss': 12.014348983764648, 'eval_runtime': 11.3016, 'eval_samples_per_second': 155.2, 'eval_steps_per_second': 9.733, 'epoch': 2.44}
# {'eval_loss': 11.034799575805664, 'eval_runtime': 11.2067, 'eval_samples_per_second': 156.514, 'eval_steps_per_second': 9.816, 'epoch': 2.54}
# {'eval_loss': 11.66645622253418, 'eval_runtime': 11.1774, 'eval_samples_per_second': 156.923, 'eval_steps_per_second': 9.841, 'epoch': 2.64}
# {'eval_loss': 11.102401733398438, 'eval_runtime': 11.2144, 'eval_samples_per_second': 156.406, 'eval_steps_per_second': 9.809, 'epoch': 2.73}
# {'eval_loss': 10.553803443908691, 'eval_runtime': 11.2581, 'eval_samples_per_second': 155.799, 'eval_steps_per_second': 9.771, 'epoch': 2.83}
# {'loss': 7.4179, 'learning_rate': 5.9963983931292414e-06, 'epoch': 2.93}
# {'eval_loss': 12.279008865356445, 'eval_runtime': 11.2511, 'eval_samples_per_second': 155.896, 'eval_steps_per_second': 9.777, 'epoch': 2.93}
# {'eval_loss': 11.287729263305664, 'eval_runtime': 11.2427, 'eval_samples_per_second': 156.012, 'eval_steps_per_second': 9.784, 'epoch': 3.03}
# {'eval_loss': 10.674988746643066, 'eval_runtime': 11.2135, 'eval_samples_per_second': 156.419, 'eval_steps_per_second': 9.81, 'epoch': 3.12}
# {'eval_loss': 10.228076934814453, 'eval_runtime': 11.2368, 'eval_samples_per_second': 156.094, 'eval_steps_per_second': 9.789, 'epoch': 3.22}
# {'eval_loss': 13.29111385345459, 'eval_runtime': 11.2489, 'eval_samples_per_second': 155.926, 'eval_steps_per_second': 9.779, 'epoch': 3.32}
# {'loss': 6.8135, 'learning_rate': 5.7539825460590106e-06, 'epoch': 3.42}
# {'eval_loss': 13.672258377075195, 'eval_runtime': 11.2579, 'eval_samples_per_second': 155.802, 'eval_steps_per_second': 9.771, 'epoch': 3.42}
# {'eval_loss': 11.3523530960083, 'eval_runtime': 11.2465, 'eval_samples_per_second': 155.96, 'eval_steps_per_second': 9.781, 'epoch': 3.52}
# {'eval_loss': 10.115604400634766, 'eval_runtime': 11.252, 'eval_samples_per_second': 155.884, 'eval_steps_per_second': 9.776, 'epoch': 3.61}
# {'eval_loss': 10.650854110717773, 'eval_runtime': 11.2856, 'eval_samples_per_second': 155.419, 'eval_steps_per_second': 9.747, 'epoch': 3.71}
# {'eval_loss': 11.977373123168945, 'eval_runtime': 11.2288, 'eval_samples_per_second': 156.205, 'eval_steps_per_second': 9.796, 'epoch': 3.81}
# {'loss': 6.376, 'learning_rate': 5.51156669898878e-06, 'epoch': 3.91}
# {'eval_loss': 10.09786319732666, 'eval_runtime': 11.1991, 'eval_samples_per_second': 156.62, 'eval_steps_per_second': 9.822, 'epoch': 3.91}
# {'eval_loss': 11.752801895141602, 'eval_runtime': 11.2574, 'eval_samples_per_second': 155.809, 'eval_steps_per_second': 9.771, 'epoch': 4.0}
# {'eval_loss': 12.126781463623047, 'eval_runtime': 11.2726, 'eval_samples_per_second': 155.599, 'eval_steps_per_second': 9.758, 'epoch': 4.1}
# {'eval_loss': 10.558156967163086, 'eval_runtime': 11.2709, 'eval_samples_per_second': 155.622, 'eval_steps_per_second': 9.76, 'epoch': 4.2}
# {'eval_loss': 11.881783485412598, 'eval_runtime': 11.2804, 'eval_samples_per_second': 155.491, 'eval_steps_per_second': 9.751, 'epoch': 4.3}
# {'loss': 5.4712, 'learning_rate': 5.269150851918548e-06, 'epoch': 4.39}
# {'eval_loss': 11.999613761901855, 'eval_runtime': 11.2593, 'eval_samples_per_second': 155.783, 'eval_steps_per_second': 9.77, 'epoch': 4.39}
# {'eval_loss': 10.893257141113281, 'eval_runtime': 11.2645, 'eval_samples_per_second': 155.711, 'eval_steps_per_second': 9.765, 'epoch': 4.49}
# {'eval_loss': 11.299586296081543, 'eval_runtime': 11.2448, 'eval_samples_per_second': 155.983, 'eval_steps_per_second': 9.782, 'epoch': 4.59}
# {'eval_loss': 11.455036163330078, 'eval_runtime': 11.2889, 'eval_samples_per_second': 155.374, 'eval_steps_per_second': 9.744, 'epoch': 4.69}
# {'eval_loss': 10.823938369750977, 'eval_runtime': 11.3092, 'eval_samples_per_second': 155.095, 'eval_steps_per_second': 9.727, 'epoch': 4.79}
# {'loss': 5.4786, 'learning_rate': 5.026735004848317e-06, 'epoch': 4.88}
# {'eval_loss': 13.404236793518066, 'eval_runtime': 11.2881, 'eval_samples_per_second': 155.384, 'eval_steps_per_second': 9.745, 'epoch': 4.88}
# {'eval_loss': 12.030879020690918, 'eval_runtime': 11.2557, 'eval_samples_per_second': 155.832, 'eval_steps_per_second': 9.773, 'epoch': 4.98}
# {'eval_loss': 11.637438774108887, 'eval_runtime': 11.2261, 'eval_samples_per_second': 156.244, 'eval_steps_per_second': 9.799, 'epoch': 5.08}
# {'eval_loss': 11.891947746276855, 'eval_runtime': 11.2167, 'eval_samples_per_second': 156.374, 'eval_steps_per_second': 9.807, 'epoch': 5.18}
# {'eval_loss': 11.000919342041016, 'eval_runtime': 11.2543, 'eval_samples_per_second': 155.851, 'eval_steps_per_second': 9.774, 'epoch': 5.27}
# {'loss': 4.5639, 'learning_rate': 4.784803989472226e-06, 'epoch': 5.37}
# {'eval_loss': 12.639256477355957, 'eval_runtime': 11.2857, 'eval_samples_per_second': 155.418, 'eval_steps_per_second': 9.747, 'epoch': 5.37}
# {'eval_loss': 11.396954536437988, 'eval_runtime': 11.2664, 'eval_samples_per_second': 155.684, 'eval_steps_per_second': 9.764, 'epoch': 5.47}
# {'eval_loss': 13.717068672180176, 'eval_runtime': 11.2579, 'eval_samples_per_second': 155.801, 'eval_steps_per_second': 9.771, 'epoch': 5.57}
# {'eval_loss': 12.989912986755371, 'eval_runtime': 11.2819, 'eval_samples_per_second': 155.47, 'eval_steps_per_second': 9.75, 'epoch': 5.66}
# {'eval_loss': 10.707716941833496, 'eval_runtime': 11.2536, 'eval_samples_per_second': 155.862, 'eval_steps_per_second': 9.775, 'epoch': 5.76}
# {'loss': 4.5317, 'learning_rate': 4.5423881424019945e-06, 'epoch': 5.86}
# {'eval_loss': 12.325115203857422, 'eval_runtime': 11.2798, 'eval_samples_per_second': 155.499, 'eval_steps_per_second': 9.752, 'epoch': 5.86}
# {'eval_loss': 13.869563102722168, 'eval_runtime': 11.2923, 'eval_samples_per_second': 155.327, 'eval_steps_per_second': 9.741, 'epoch': 5.96}
# {'eval_loss': 13.445354461669922, 'eval_runtime': 11.2506, 'eval_samples_per_second': 155.903, 'eval_steps_per_second': 9.777, 'epoch': 6.05}
# {'eval_loss': 11.605621337890625, 'eval_runtime': 11.2416, 'eval_samples_per_second': 156.028, 'eval_steps_per_second': 9.785, 'epoch': 6.15}
# {'eval_loss': 11.869029998779297, 'eval_runtime': 11.2575, 'eval_samples_per_second': 155.807, 'eval_steps_per_second': 9.771, 'epoch': 6.25}
# {'loss': 3.7667, 'learning_rate': 4.299972295331763e-06, 'epoch': 6.35}
# {'eval_loss': 11.768095016479492, 'eval_runtime': 11.2496, 'eval_samples_per_second': 155.916, 'eval_steps_per_second': 9.778, 'epoch': 6.35}
# {'eval_loss': 12.277432441711426, 'eval_runtime': 11.2916, 'eval_samples_per_second': 155.337, 'eval_steps_per_second': 9.742, 'epoch': 6.45}
# {'eval_loss': 12.22691535949707, 'eval_runtime': 11.2759, 'eval_samples_per_second': 155.553, 'eval_steps_per_second': 9.755, 'epoch': 6.54}
# {'eval_loss': 11.637199401855469, 'eval_runtime': 11.2513, 'eval_samples_per_second': 155.894, 'eval_steps_per_second': 9.777, 'epoch': 6.64}
# {'eval_loss': 11.845940589904785, 'eval_runtime': 11.2831, 'eval_samples_per_second': 155.454, 'eval_steps_per_second': 9.749, 'epoch': 6.74}
# {'loss': 3.426, 'learning_rate': 4.057556448261532e-06, 'epoch': 6.84}
# {'eval_loss': 13.049178123474121, 'eval_runtime': 11.2859, 'eval_samples_per_second': 155.415, 'eval_steps_per_second': 9.747, 'epoch': 6.84}
# {'train_runtime': 2072.7044, 'train_samples_per_second': 59.241, 'train_steps_per_second': 7.411, 'train_loss': 20.636435285295757, 'epoch': 6.84}
# {'eval_loss': 10.09786319732666, 'eval_runtime': 11.2414, 'eval_samples_per_second': 156.031, 'eval_steps_per_second': 9.785, 'epoch': 6.84}
# training with following hparams:
# {'batch_size': 8, 'learning_rate': 7e-06, 'repeats': 0, 'weight_decay': 0.01}
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# {'eval_loss': 189.07080078125, 'eval_runtime': 11.3044, 'eval_samples_per_second': 155.161, 'eval_steps_per_second': 9.731, 'epoch': 0.1}
# {'eval_loss': 164.88380432128906, 'eval_runtime': 11.234, 'eval_samples_per_second': 156.134, 'eval_steps_per_second': 9.792, 'epoch': 0.2}
# {'eval_loss': 125.93949890136719, 'eval_runtime': 11.2241, 'eval_samples_per_second': 156.271, 'eval_steps_per_second': 9.8, 'epoch': 0.29}
# {'eval_loss': 92.71209716796875, 'eval_runtime': 11.2269, 'eval_samples_per_second': 156.233, 'eval_steps_per_second': 9.798, 'epoch': 0.39}
# {'loss': 172.9936, 'learning_rate': 3.74295010845987e-06, 'epoch': 0.49}
# {'eval_loss': 70.6252212524414, 'eval_runtime': 11.2433, 'eval_samples_per_second': 156.004, 'eval_steps_per_second': 9.784, 'epoch': 0.49}
# {'eval_loss': 51.804935455322266, 'eval_runtime': 11.1922, 'eval_samples_per_second': 156.717, 'eval_steps_per_second': 9.828, 'epoch': 0.59}
# {'eval_loss': 35.340023040771484, 'eval_runtime': 11.1843, 'eval_samples_per_second': 156.827, 'eval_steps_per_second': 9.835, 'epoch': 0.68}
# {'eval_loss': 22.04935073852539, 'eval_runtime': 11.1445, 'eval_samples_per_second': 157.387, 'eval_steps_per_second': 9.87, 'epoch': 0.78}
# {'eval_loss': 14.089932441711426, 'eval_runtime': 11.1203, 'eval_samples_per_second': 157.729, 'eval_steps_per_second': 9.892, 'epoch': 0.88}
# {'loss': 42.8348, 'learning_rate': 6.965576949716027e-06, 'epoch': 0.98}
# {'eval_loss': 13.39174747467041, 'eval_runtime': 11.1234, 'eval_samples_per_second': 157.685, 'eval_steps_per_second': 9.889, 'epoch': 0.98}
# {'eval_loss': 14.247187614440918, 'eval_runtime': 11.1427, 'eval_samples_per_second': 157.412, 'eval_steps_per_second': 9.872, 'epoch': 1.07}
# {'eval_loss': 15.550774574279785, 'eval_runtime': 11.1576, 'eval_samples_per_second': 157.202, 'eval_steps_per_second': 9.859, 'epoch': 1.17}
# {'eval_loss': 13.797327995300293, 'eval_runtime': 11.1154, 'eval_samples_per_second': 157.799, 'eval_steps_per_second': 9.896, 'epoch': 1.27}
# {'eval_loss': 15.22275161743164, 'eval_runtime': 11.1511, 'eval_samples_per_second': 157.293, 'eval_steps_per_second': 9.864, 'epoch': 1.37}
# {'loss': 9.2827, 'learning_rate': 6.723161102645796e-06, 'epoch': 1.46}
# {'eval_loss': 11.943194389343262, 'eval_runtime': 11.1868, 'eval_samples_per_second': 156.792, 'eval_steps_per_second': 9.833, 'epoch': 1.46}
# {'eval_loss': 13.769210815429688, 'eval_runtime': 11.228, 'eval_samples_per_second': 156.217, 'eval_steps_per_second': 9.797, 'epoch': 1.56}
# {'eval_loss': 12.054460525512695, 'eval_runtime': 11.1903, 'eval_samples_per_second': 156.743, 'eval_steps_per_second': 9.83, 'epoch': 1.66}
# {'eval_loss': 13.423868179321289, 'eval_runtime': 11.1778, 'eval_samples_per_second': 156.918, 'eval_steps_per_second': 9.841, 'epoch': 1.76}
# {'eval_loss': 11.625014305114746, 'eval_runtime': 11.1978, 'eval_samples_per_second': 156.638, 'eval_steps_per_second': 9.823, 'epoch': 1.86}
# {'loss': 8.5192, 'learning_rate': 6.480745255575564e-06, 'epoch': 1.95}
# {'eval_loss': 10.81595516204834, 'eval_runtime': 11.2265, 'eval_samples_per_second': 156.237, 'eval_steps_per_second': 9.798, 'epoch': 1.95}
# {'eval_loss': 12.807709693908691, 'eval_runtime': 11.2535, 'eval_samples_per_second': 155.863, 'eval_steps_per_second': 9.775, 'epoch': 2.05}
# {'eval_loss': 12.564526557922363, 'eval_runtime': 11.2218, 'eval_samples_per_second': 156.303, 'eval_steps_per_second': 9.802, 'epoch': 2.15}
# {'eval_loss': 13.455673217773438, 'eval_runtime': 11.1963, 'eval_samples_per_second': 156.659, 'eval_steps_per_second': 9.825, 'epoch': 2.25}
# {'eval_loss': 10.987509727478027, 'eval_runtime': 11.2514, 'eval_samples_per_second': 155.892, 'eval_steps_per_second': 9.777, 'epoch': 2.54}

# %%
#Test set performance
best_model = get_model_by_name(FINAL_MODEL_PATH)
trainer_best_model = Trainer(model=best_model)

predictions = trainer_best_model.predict(test_dataset)
preds = predictions.predictions.flatten() 
labels = predictions.label_ids

if TARGET_COL == 'revenue_worldwide_BOM':
    preds = np.expm1(preds)
    labels = np.expm1(labels)


mse = ((preds-labels)**2).mean()
mae = (np.abs(preds-labels)).mean()
errors = {'MAE':mae,'MSE':mse,'RMSE':np.sqrt(mse)}
pd.DataFrame([errors]).to_csv(TEST_PERFORMANCE_PATH,
                              index=False)
# Out:
# ***** Running Prediction *****
#   Num examples = 1754
#   Batch size = 8

# %%
import matplotlib.pyplot as plt
from scipy.stats import boxcox
plt.hist(np.log1p(labels),bins=40)
plt.hist(np.log1p(preds),bins=40)

#plt.xscale('log')
# Out:
# (array([  2.,   4.,  17.,  34.,  53.,  64.,  70., 102.,  81.,  89.,  91.,
#          84.,  74.,  73.,  76.,  55.,  56.,  51.,  48.,  41.,  26.,  30.,
#          31.,  20.,  27.,  29.,  21.,  24.,  20.,  14.,  30.,  20.,  27.,
#          24.,  31.,  22.,  27.,  52.,  45.,  69.]),
#  array([ 8.904737 ,  9.151753 ,  9.398769 ,  9.645784 ,  9.8928   ,
#         10.139816 , 10.386832 , 10.633848 , 10.880863 , 11.127879 ,
#         11.374895 , 11.621911 , 11.868927 , 12.115942 , 12.362958 ,
#         12.609974 , 12.85699  , 13.104006 , 13.351021 , 13.598037 ,
#         13.845053 , 14.092069 , 14.339085 , 14.5861   , 14.833116 ,
#         15.080132 , 15.3271475, 15.574163 , 15.821178 , 16.068195 ,
#         16.31521  , 16.562225 , 16.809242 , 17.056257 , 17.303274 ,
#         17.55029  , 17.797304 , 18.044321 , 18.291336 , 18.538353 ,
#         18.785368 ], dtype=float32),
#  <BarContainer object of 40 artists>)
